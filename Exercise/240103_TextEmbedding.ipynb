# %% [markdown]
# <h1 style = 'text-align: center'> <b>Week 04: Text Embedding</b> </h1>

# %% [markdown]
# - Name: Võ Nguyễn Hoàng Kim
# - Mentee ID: 240103

# %%
# !pip install underthesea
import underthesea
from gensim.models import Word2Vec
import random
from underthesea import word_tokenize
from underthesea import text_normalize
import re
# Out:
# Requirement already satisfied: underthesea in /opt/conda/lib/python3.10/site-packages (6.8.4)
# Requirement already satisfied: Click>=6.0 in /opt/conda/lib/python3.10/site-packages (from underthesea) (8.1.7)
# Requirement already satisfied: python-crfsuite>=0.9.6 in /opt/conda/lib/python3.10/site-packages (from underthesea) (0.9.11)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from underthesea) (3.2.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from underthesea) (4.66.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from underthesea) (2.32.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.4.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.2.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from underthesea) (6.0.2)
# Requirement already satisfied: underthesea-core==1.0.4 in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.0.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->underthesea) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (2024.8.30)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (1.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (3.5.0)

# %% [markdown]
# # 1. Read data

# %%
# open data
def readData(file_path, encoding='utf-8'):
    with open(file_path, 'r', encoding = encoding) as file:
        return file.read().splitlines()
    
wiki_doc = readData("/kaggle/input/cleaned-viwik18-dataset/clean_viwik18.txt")
stop_words = readData("/kaggle/input/vietnamese-stop-words/vietnamese-stopwords.txt")

# %% [markdown]
# # 2. Preprocess text

# %%
# normalize text 
def normalizeText(article):
    return text_normalize(article)

# remove unnecessary punctuation 
def cleanText(article):    
    # remove several punctuation such as ; , ( ) [ ] ... 
    return re.sub(r'[^\w\s/:.-]', '', article)

# remove stop word
def removeStopWords(article, stop_words):
    # using regex with re.sub to remove stop word (better than using String replace)
    stop_words_pattern = r'\b(?:' + '|'.join(map(re.escape, stop_words)) + r')\b'
    cleaned_text = re.sub(stop_words_pattern, '', article)
    # remove redundant spaces
    cleaned_text = ' '.join(cleaned_text.split())
    return cleaned_text

# tokenize by underthesea
def tokenization(article):
    return word_tokenize(article)

def prepocessText(articles_content, stop_words):
    processed_articles = []
    for article in articles_content:
        # lower case
        article = article.lower()
        # normalize text
        normalized_text = normalizeText(article)
        # clean text
        cleaned_text = cleanText(normalized_text)
        # remove stop words
        removedStopWords_text = removeStopWords(cleaned_text, stop_words)
        # tokenize text
        tokens = tokenization(removedStopWords_text)        
        # re-clean tokens to remove unnecessary characters like '-', '.', etc.
        cleaned_tokens = [token for token in tokens if re.search(r'[a-zA-Z0-9]', token)]
        # add tokens in result list
        processed_articles.append(cleaned_tokens)
    return processed_articles

# %%
# take 1000 random sentences to make the sample data
sample_sentence = wiki_doc[:1000]

# preprocess the sample data
sample_tokens = prepocessText(sample_sentence, stop_words)
sample_tokens[:10]
# Out:
# [['trang'],
#  ['internet', 'society'],
#  ['internet',
#   'society isoc',
#   'tổ chức',
#   'quốc tế',
#   'hoạt động',
#   'phi lợi nhuận',
#   'phi phủ',
#   'bao',
#   'thành viên',
#   'trình độ',
#   'chuyên ngành',
#   'tổ chức',
#   'trọng tiêu chuẩn',
#   'giáo dục',
#   'sách',
#   'bốn',
#   'tổ chức',
#   'thành viên',
#   'sáu',
#   'thành viên',
#   'isoc',
#   'bao',
#   'cộng đồng',
#   'internet',
#   'chi tiết thể',
#   'website',
#   'isoc'],
#  ['internet',
#   'society',
#   'nằm',
#   'thủ đô',
#   'washington',
#   'dc',
#   'hoa',
#   'kỳ geneva',
#   'thụy sĩ',
#   'hội viên',
#   'bao',
#   'bốn',
#   'tổ chức',
#   'thành viên',
#   'sáu',
#   'thành viên',
#   'thể lập',
#   'chi nhánh',
#   'tổ chức',
#   'tùy sở',
#   'tổ chức',
#   'chín',
#   'chi nhánh',
#   'toàn',
#   'giới'],
#  ['nhiệm vụ', 'mục đích', 'hoạt động'],
#  ['bảo đảm',
#   'cổ vũ',
#   'phát triển',
#   'rộng',
#   'internet',
#   'thuận lợi',
#   'toàn',
#   'giới'],
#  [],
#  ['lịch sử', 'internet'],
#  ['liên kết'],
#  ['isoc', 'việt nam'],
#  ['trang', 'chủ', 'toàn cầu'],
#  ['ietf',
#   'and the',
#   'internet',
#   'society',
#   'internet',
#   'engineering',
#   'task',
#   'force',
#   'isoc',
#   'vint',
#   'cerf',
#   'tám',
#   'sáu',
#   'chín',
#   'chín'],
#  ['l',
#   'association',
#   'internationale',
#   'de',
#   'lutte',
#   'contre la',
#   'cybercriminalité',
#   'lưu'],
#  ['public', 'interest', 'registry'],
#  ['tiếng', 'việt'],
#  ['tiếng',
#   'việt',
#   'gọi',
#   'tiếng',
#   'việt nam',
#   'việt ngữ',
#   'ngôn ngữ',
#   'việt ngôn ngữ thức',
#   'việt nam',
#   'tiếng mẹ đẻ',
#   'tám',
#   'trăm',
#   'dân cư',
#   'việt nam',
#   'bốn triệu',
#   'việt',
#   'hải ngoại',
#   'tiếng',
#   'việt',
#   'ngôn ngữ',
#   'hai',
#   'dân tộc thiểu',
#   'việt nam',
#   'mặc',
#   'tiếng',
#   'việt',
#   'vựng',
#   'vay mượn',
#   'tiếng',
#   'hán',
#   'chữ',
#   'nôm',
#   'hệ',
#   'chữ',
#   'dựa',
#   'chữ',
#   'hán',
#   'viết',
#   'tiếng',
#   'việt',
#   'coi ngôn',
#   'ngữ ngữ',
#   'hệ nam',
#   'tiếng',
#   'việt',
#   'bảng',
#   'chữ',
#   'latinh',
#   'gọi',
#   'chữ',
#   'quốc ngữ',
#   'dấu',
#   'viết'],
#  ['tiếng',
#   'việt thức',
#   'ghi',
#   'hiến pháp',
#   'cộng hòa',
#   'xã hội chủ nghĩa việt nam',
#   'hai',
#   'chương',
#   'i mục',
#   'ngôn ngữ',
#   'quốc gia',
#   'việt nam',
#   'tiếng',
#   'việt',
#   'bao',
#   'phát âm',
#   'tiếng',
#   'việt',
#   'chữ',
#   'quốc ngữ',
#   'viết nhiên',
#   'hiện văn',
#   'quy định',
#   'giọng',
#   'chuẩn quốc',
#   'tiếng',
#   'việt văn',
#   'viết',
#   'quy định',
#   'tả',
#   'tiếng',
#   'việt',
#   'thuật ngữ',
#   'tiếng',
#   'việt',
#   'áp dụng',
#   'sách giáo khoa',
#   'báo',
#   'văn ngành',
#   'giáo dục',
#   'nêu',
#   'quyết định',
#   'giáo dục',
#   'hai',
#   'bốn',
#   'qđ',
#   'chín',
#   'tám',
#   'bốn',
#   'thụ hưởng',
#   'giáo dục',
#   'lĩnh vực',
#   'xã hội'],
#  ['lưu',
#   'nhầm lẫn',
#   'việt ngữ',
#   'tiếng',
#   'quảng đông',
#   'ngôn ngữ',
#   'miền',
#   'nam',
#   'trung quốc',
#   'hồng',
#   'kông',
#   'ma'],
#  ['tổ chức',
#   'tiêu chuẩn',
#   'hóa',
#   'quốc tế mã',
#   'ngôn ngữ',
#   'hai',
#   'chữ',
#   'tiếng',
#   'việt',
#   'vi mã',
#   'ngôn ngữ',
#   'chữ',
#   'tiếng',
#   'việt',
#   'vie'],
#  ['xếp'],
#  ['sở',
#   'khoa học',
#   'đa ngôn ngữ',
#   'học thừa',
#   'tiếng',
#   'việt',
#   'quan hệ gũi',
#   'tiếng',
#   'mường',
#   'xếp ngữ',
#   'chi việt',
#   'ngôn ngữ',
#   'môn',
#   'khmer hệ',
#   'nam',
#   'khu vực',
#   'đông',
#   'nam'],
#  ['ngôn ngữ',
#   'vựng',
#   'thí dụ',
#   'tiếng',
#   'việt',
#   'tương đương',
#   'tiếng',
#   'mường thay',
#   'tiếng',
#   'khmer đay',
#   'tiếng',
#   'môn',
#   'tai'],
#  ['lịch sử'],
#  ['tiếng',
#   'việt',
#   'ngôn ngữ',
#   'gốc',
#   'địa xuất thân',
#   'văn minh',
#   'nông nghiệp',
#   'khu vực',
#   'bắc',
#   'lưu vực',
#   'sông',
#   'hồng',
#   'sông',
#   'mã',
#   'việt nam'],
#  ['a',
#   'g',
#   'haudricourt',
#   'giải',
#   'chín',
#   'bốn',
#   'ngôn ngữ',
#   'việt mường',
#   'thời kỳ',
#   'đầu',
#   'công nguyên',
#   'ngôn ngữ',
#   'phương ngữ',
#   'điệu trình',
#   'giao thoa',
#   'hoa ngữ',
#   'ngữ ngữ',
#   'hệ',
#   'tai kadai',
#   'vốn',
#   'hệ thống',
#   'điệu',
#   'phát triển',
#   'hệ thống',
#   'điệu',
#   'tiếng',
#   'việt',
#   'diện mạo',
#   'quy luật',
#   'hình thành',
#   'điệu điệu',
#   'kỷ vi điệu',
#   'phát triển',
#   'ổn định',
#   'kỷ xii',
#   'sáu điệu',
#   'phụ âm',
#   'đầu',
#   'biến đổi',
#   'trình',
#   'biến đổi',
#   'phụ âm rụng',
#   'đi',
#   'kết thúc',
#   'âm tiết',
#   'phụ âm đầu',
#   'lẫn lộn',
#   'vô hữu',
#   'tách biệt'],
#  ['ví dụ', 'a g', 'haudricourt'],
#  ['ảnh hưởng', 'trung hoa'],
#  ['tiếng',
#   'việt',
#   'ngôn ngữ',
#   'sinh hoạt',
#   'giao tiếp',
#   'dân lập',
#   'giai đoạn',
#   'đầu',
#   'công nguyên',
#   'tiếng',
#   'việt',
#   'âm tiếng',
#   'trung tiếng',
#   'trung ảnh hưởng',
#   'việt nam',
#   'thông',
#   'đường',
#   'bao',
#   'giai đoạn',
#   'tiếng',
#   'việt âm',
#   'vay mượn',
#   'tiếng',
#   'trung tác giả',
#   'mai',
#   'ngọc chừ',
#   'vũ đức nghiệu',
#   'hoàng trọng',
#   'phiến',
#   'sách sở',
#   'ngôn ngữ',
#   'học',
#   'tiếng',
#   'việt',
#   'chia trình',
#   'tiếp xúc',
#   'hán',
#   'việt',
#   'thành',
#   'hai',
#   'giai đoạn'],
#  ['giai đoạn',
#   'đầu',
#   'công nguyên',
#   'đầu',
#   'thời',
#   'đường',
#   'vựng',
#   'tiếng',
#   'hán',
#   'ảnh hưởng',
#   'tiếng',
#   'việt',
#   'giai đoạn',
#   'gọi',
#   'hán',
#   'cổ'],
#  ['giai đoạn',
#   'thời',
#   'đường',
#   'trở vựng',
#   'tiếng',
#   'hán',
#   'ảnh hưởng',
#   'tiếng',
#   'việt',
#   'giai đoạn',
#   'gọi',
#   'hán',
#   'việt'],
#  ['hán', 'cổ', 'hán việt', 'gọi', 'gốc', 'hán'],
#  ['ngữ',
#   'hán',
#   'cổ thể',
#   'đầu',
#   'gan',
#   'ghế',
#   'chè',
#   'ngà',
#   'chén chém',
#   'chìm',
#   'buồng',
#   'buồn buồm',
#   'mùi',
#   'mùa',
#   'hán',
#   'cổ',
#   'gốc',
#   'hán',
#   'du nhập',
#   'tiếng',
#   'việt',
#   'đồng',
#   'hóa thông',
#   'hoạt động',
#   'xã hội',
#   'việt'],
#  ['hệ thống',
#   'hán',
#   'việt',
#   'tiếng',
#   'việt',
#   'đọc',
#   'chữ',
#   'hán ngữ',
#   'âm hiện',
#   'tiếng',
#   'việt',
#   'vựng',
#   'tiếng',
#   'việt',
#   'hàng loạt',
#   'yếu tố',
#   'hán',
#   'việt',
#   'chủ',
#   'tâm minh đức',
#   'thiên nguyên nghĩa',
#   'đọc',
#   'nhiệt náo',
#   'thành',
#   'náo nhiệt',
#   'phóng',
#   'thành',
#   'phóng',
#   'thành',
#   'bảo đảm',
#   'rút',
#   'gọn',
#   'thừa trần',
#   'thành',
#   'trần lạc',
#   'hoa sinh',
#   'thành lạc',
#   'đọc',
#   'chệch',
#   'đi',
#   'tiếp thu',
#   'thành',
#   'tiếp thụ',
#   'tháp',
#   'nhập',
#   'thành',
#   'sáp nhập',
#   'thống kế',
#   'thành',
#   'thống kê cư',
#   'thành cư',
#   'vãn cảnh',
#   'thành',
#   'vãng cảnh',
#   'khuyến mãi',
#   'thành',
#   'khuyến mại',
#   'đổi nghĩa',
#   'phương phi',
#   'tiếng',
#   'hán nghĩa',
#   'hoa cỏ',
#   'thơm tho',
#   'tiếng',
#   'việt',
#   'béo',
#   'bồi hồi',
#   'tiếng',
#   'hán nghĩa',
#   'đi đi',
#   'tiếng',
#   'việt',
#   'thành',
#   'bồn chồn',
#   'xúc động',
#   'mặt',
#   'trung quốc',
#   'gọi',
#   'thái sơn',
#   'hoàng hà',
#   'cổ thụ việt',
#   'đọc',
#   'núi',
#   'thái sơn',
#   'sông',
#   'hoàng hà',
#   'cổ thụ',
#   'quy ước',
#   'ngôn ngữ',
#   'đọc',
#   'sai',
#   'tiếng',
#   'hán chấp',
#   'rộng rãi',
#   'nghiên cứu',
#   'ngôn ngữ',
#   'tiếng',
#   'việt quan',
#   'quản lý',
#   'tổ chức',
#   'xã hội',
#   'nghề nghiệp',
#   'lẫn',
#   'khoa học',
#   'việt nam',
#   'tiếng',
#   'chuẩn',
#   'hóa',
#   'vựng',
#   'mượn',
#   'tiếng',
#   'cạnh',
#   'sai',
#   'chấp quan ngại',
#   'lo ngại vấn nạn',
#   'nan giải',
#   'viết',
#   'thành',
#   'vô hình',
#   'vô hình dung',
#   'việt dã',
#   'chạy',
#   'trứ tác tác',
#   'phong phong',
#   'phanh',
#   'bàng quan',
#   'bàng quang',
#   'đào ngũ',
#   'đảo ngũ',
#   'tham quan',
#   'thành',
#   'thăm',
#   'quan xán',
#   'lạn',
#   'thành',
#   'lạng'],
#  ['yếu tố',
#   'hán',
#   'việt ngữ',
#   'đặc trưng',
#   'tiếng',
#   'việt',
#   'tiếng',
#   'hán sĩ',
#   'diện',
#   'phi công',
#   'bao',
#   'sống động sinh đẻ',
#   'tỉ lệ',
#   'vay mượn',
#   'tiếng',
#   'hán',
#   'tiếng',
#   'việt ước',
#   'nghiên cứu',
#   'hán',
#   'việt',
#   'chiếm',
#   'bảy',
#   'trăm',
#   'vốn',
#   'phong luận',
#   'khoa học',
#   'tác giả',
#   'lê',
#   'nguyễn lưu sách',
#   'chữ',
#   'hán',
#   'chữ',
#   'nôm',
#   'lĩnh vực',
#   'chuyên môn',
#   'khoa học',
#   'tỉ lệ thể',
#   'tám',
#   'trăm',
#   'xét',
#   'văn ngữ',
#   'tiểu thuyết',
#   'hai',
#   'tám',
#   'trăm',
#   'kịch',
#   'rút',
#   'tám',
#   'chín trăm',
#   'ngôn ngữ',
#   'hằng',
#   'tỷ lệ',
#   'đi',
#   'đại đa',
#   'việt',
#   'hóa thức',
#   'việt',
#   'tiếng',
#   'việt',
#   'gọi',
#   'thủ tướng',
#   'tiếng',
#   'hoa',
#   'tổng lý',
#   'tiếng',
#   'việt',
#   'truyền hình',
#   'tiếng',
#   'hoa',
#   'điện thị',
#   'tiếng',
#   'việt',
#   'thành phố',
#   'tiếng',
#   'hoa',
#   'đô thị',
#   'chữ',
#   'thủ tướng',
#   'truyền hình',
#   'thành phố',
#   'hán',
#   'việt',
#   'hoa',
#   'tiếng',
#   'việt',
#   'vay mượn',
#   'tiếng',
#   'hán sắc',
#   'ảnh hưởng',
#   'văn hóa',
#   'hán',
#   'lợi dụng',
#   'thành tựu',
#   'ngôn ngữ',
#   'tiếng',
#   'hán',
#   'cải tiến'],
#  ['đầu',
#   'kỷ xi',
#   'nho học',
#   'phát triển',
#   'học',
#   'văn chữ',
#   'nho đẩy',
#   'tầng lớp',
#   'trí thức',
#   'rộng',
#   'tiền đề văn chương',
#   'việt',
#   'chữ nho',
#   'cực kỳ',
#   'phát triển',
#   'văn thư',
#   'nổi tiếng',
#   'nam quốc',
#   'sơn hà',
#   'sông nguyệt'],
#  ['hệ thống',
#   'chữ viết',
#   'xây dựng',
#   'việt',
#   'nguyên tắc',
#   'ghi âm tiết',
#   'phát triển',
#   'chữ',
#   'nôm tiện',
#   'học',
#   'chữ',
#   'hán',
#   'chữ',
#   'nôm',
#   'việt',
#   'ngô',
#   'nhậm biên soạn',
#   'sách',
#   'tam thiên giải',
#   'âm tam',
#   'thiên giải',
#   'âm lược',
#   'dạy',
#   'chữ',
#   'hán',
#   'nôm thông',
#   'đáp ứng',
#   'nhu cầu',
#   'thiết chữ',
#   'nghĩa',
#   'chữ',
#   'câu',
#   'bốn',
#   'chữ',
#   'hiệp vần',
#   'tức',
#   'vần',
#   'lưng',
#   'tiếng',
#   'tư',
#   'câu',
#   'đầu hiệp',
#   'tiếng',
#   'hai',
#   'câu',
#   'mãi',
#   'chữ',
#   'bảy',
#   'câu',
#   'ví dụ',
#   'thiên trời',
#   'địa đất',
#   'cử cất',
#   'tồn tử',
#   'tôn',
#   'cháu',
#   'lục',
#   'sáu',
#   'tam gia quốc',
#   'tiền',
#   'hậu ngưu',
#   'trâu mã',
#   'ngựa',
#   'cự',
#   'cựa nha',
#   'vô hữu khuyển',
#   'chó',
#   'dương',
#   'dê',
#   'v',
#   'v',
#   'trần văn giáp',
#   'quyển',
#   'sách',
#   'dạy học',
#   'vỡ',
#   'chữ',
#   'hán tác giả thể',
#   'coi',
#   'sách',
#   'điển hán',
#   'việt thông',
#   'phổ biến',
#   'kỷ xviii',
#   'thời',
#   'sách',
#   'nam',
#   'ngọc âm',
#   'nam',
#   'sách',
#   'nhật dụng',
#   'đàm thiên văn',
#   'đại nam',
#   'quốc ngữ',
#   'chữ',
#   'nôm',
#   'văn học',
#   'việt nam',
#   'phát triển',
#   'rực rỡ',
#   'đỉnh',
#   'truyện kiều',
#   'nguyễn du tiếng',
#   'việt',
#   'thể hiện',
#   'chữ',
#   'nôm',
#   'thời kỳ',
#   'tiếng',
#   'việt',
#   'việt thể',
#   'văn chữ',
#   'nôm',
#   'học',
#   'chữ',
#   'nôm thể',
#   'đọc',
#   'viết',
#   'chữ',
#   'nôm'],
#  ['chữ', 'nôm thức', 'hành vua', 'quang trung bảy', 'tám', 'chín'],
#  ['ảnh hưởng', 'châu âu'],
#  ['pháp',
#   'xâm lược',
#   'việt nam',
#   'nửa',
#   'kỷ xix',
#   'tiếng',
#   'pháp',
#   'thay',
#   'chữ nho ngôn ngữ thức',
#   'giáo dục',
#   'hành ngoại giao',
#   'chữ',
#   'quốc ngữ',
#   'vốn',
#   'truyền giáo',
#   'châu âu',
#   'hai',
#   'tu sĩ',
#   'bồ đào',
#   'nha',
#   'gaspar',
#   'amaral',
#   'antonio',
#   'barbosa',
#   'mục đích',
#   'ký',
#   'latinh',
#   'biểu hiện',
#   'tiếng',
#   'việt',
#   'phổ biến',
#   'việt',
#   'tiếp'],
#  ['tờ',
#   'gia định',
#   'báo',
#   'tờ',
#   'báo',
#   'phát hành',
#   'chữ',
#   'quốc ngữ',
#   'nam kỳ',
#   'tám',
#   'sáu',
#   'móng',
#   'phát triển',
#   'xu hướng',
#   'chữ',
#   'quốc ngữ',
#   'chữ viết',
#   'thức',
#   'việt nam',
#   'độc lập'],
#  ['mặt',
#   'khái niệm trị',
#   'xã hội',
#   'kỹ thuật',
#   'nhập thuật',
#   'ngữ ngữ',
#   'hai',
#   'xu hướng',
#   'thức',
#   'nhập',
#   'thuật ngữ'],
#  ['nhập',
#   'phiên âm ngôn ngữ',
#   'phương tây',
#   'chủ yếu',
#   'tiếng',
#   'pháp',
#   'tầng lớp',
#   'thị dân',
#   'vốn',
#   'thạo',
#   'chữ',
#   'hán',
#   'ghi',
#   'đông',
#   'phanh',
#   'lốp găng',
#   'pê',
#   'đan',
#   'phuốc'],
#  ['hai',
#   'nhập',
#   'tiếng',
#   'trung đảng',
#   'kinh tế',
#   'giai kính',
#   'giới',
#   'văn hoa',
#   'phương tây',
#   'hán',
#   'việt đình',
#   'nã',
#   'phá',
#   'luân tòa',
#   'bạch ốc',
#   'coi',
#   'biểu hiện',
#   'trang trọng'],
#  ['thời kỳ', 'chín', 'bốn'],
#  ['chữ',
#   'quốc ngữ',
#   'chữ',
#   'ghi âm',
#   'hai',
#   'bảy',
#   'ký',
#   'latin',
#   'sáu',
#   'dấu',
#   'đơn giản',
#   'tiện lợi',
#   'khoa học',
#   'học',
#   'thông dụng',
#   'thay',
#   'tiếng',
#   'pháp',
#   'tiếng',
#   'hán',
#   'vốn',
#   'đọc',
#   'thông dụng',
#   'việt'],
#  ['thời kỳ',
#   'chiến tranh',
#   'việt nam',
#   'phát triển',
#   'tiếng',
#   'việt thể',
#   'việt nam',
#   'dân chủ',
#   'cộng',
#   'hòa',
#   'miền',
#   'bắc',
#   'việt nam',
#   'cộng hòa',
#   'miền',
#   'nam',
#   'diễn chút',
#   'chủ yếu',
#   'hán',
#   'việt',
#   'phiên',
#   'âm tiếng'],
#  ['miền',
#   'bắc',
#   'xu hướng',
#   'việt',
#   'thay',
#   'hán',
#   'việt nghĩa',
#   'miền',
#   'nam',
#   'nguyên hán',
#   'việt',
#   'thời',
#   'chín',
#   'bốn',
#   'ví dụ',
#   'miền',
#   'nam',
#   'ngân hàng',
#   'quốc gia',
#   'miền',
#   'bắc',
#   'đổi',
#   'thành',
#   'ngân hàng',
#   'miền',
#   'nam',
#   'gọi',
#   'phi trường',
#   'miền',
#   'bắc',
#   'gọi',
#   'sân bay',
#   'miền',
#   'nam',
#   'gọi',
#   'ngũ giác',
#   'đài',
#   'miền',
#   'bắc',
#   'gọi',
#   'lầu',
#   'góc',
#   'miền',
#   'nam',
#   'gọi',
#   'nhứt chiến',
#   'miền',
#   'bắc',
#   'kiên quyết',
#   'gọi',
#   'chiến tranh giới',
#   'miền',
#   'nam',
#   'gọi',
#   'hỏa tiễn',
#   'miền',
#   'bắc',
#   'gọi',
#   'lửa',
#   'miền',
#   'nam',
#   'gọi',
#   'thủy quân',
#   'lục chiến',
#   'miền',
#   'bắc',
#   'đổi',
#   'thành',
#   'lính',
#   'thủy',
#   'đánh',
#   'ngược danh',
#   'miền',
#   'bắc',
#   'tham quan',
#   'cố trí',
#   'đăng ký',
#   'đột xuất',
#   'vô tư',
#   'v',
#   'v',
#   'miền',
#   'nam',
#   'chữ',
#   'thăm viếng',
#   'trở ngại',
#   'trục trặc',
#   'đồng',
#   'ghi',
#   'thoải mái'],
#  ['phiên',
#   'âm tiếng',
#   'miền',
#   'nam',
#   'chín',
#   'bốn',
#   'hán',
#   'việt',
#   'băng đảo',
#   'úc',
#   'đại lợi',
#   'hung gia lợi tây',
#   'miền',
#   'bắc',
#   'phiên',
#   'âm thành',
#   'xơ',
#   'len ô',
#   'xtrây li',
#   'a hung',
#   'ga',
#   'ri trừ',
#   'hán',
#   'việt',
#   'đối tượng',
#   'phổ biến pháp',
#   'đức nga',
#   'cá biệt',
#   'tiếng',
#   'trung zhuang',
#   'phiên',
#   'âm',
#   'giọng',
#   'hà nội thành',
#   'choang',
#   'khu',
#   'trị',
#   'dân tộc',
#   'choang',
#   'quảng tây',
#   'miền',
#   'nam',
#   'hiện diện',
#   'quân đội',
#   'hoa kỳ',
#   'đem',
#   'tiếng',
#   'ngôn ngữ',
#   'giao tiếp',
#   'hằng'],
#  ['việt nam thống',
#   'chín',
#   'bảy',
#   'quan hệ',
#   'bắc nam',
#   'kết nối',
#   'phổ biến',
#   'phương tiện',
#   'truyền truyền hình',
#   'toàn quốc',
#   'tiếng',
#   'việt',
#   'chuẩn',
#   'hóa việt',
#   'phổ biến',
#   'thay',
#   'hán việt',
#   'tiến triển',
#   'internet',
#   'toàn cầu',
#   'hóa',
#   'ảnh hưởng',
#   'tiếng',
#   'báo chí',
#   'đội ngũ',
#   'phóng viên',
#   'tiếng',
#   'việt',
#   'lọc',
#   'viết nguyên',
#   'ngôn ngữ'],
#  ['phân bố'],
#  ['tiếng',
#   'việt',
#   'ngôn ngữ thức',
#   'việt nam',
#   'ngôn ngữ',
#   'phổ thông',
#   'dân tộc thiểu',
#   'việt nam',
#   'tiếng',
#   'việt',
#   'triệu',
#   'hoa',
#   'kỳ canada',
#   'úc'],
#  ['ethnologue',
#   'tiếng',
#   'việt',
#   'lan',
#   'campuchia',
#   'côte',
#   'd',
#   'ivoire',
#   'đức hà lan',
#   'lào na',
#   'uy nouvelle',
#   'calédonie',
#   'lan pháp',
#   'philippines',
#   'cộng',
#   'hòa',
#   'séc',
#   'sénégal thái lan',
#   'trung quốc',
#   'vanuatu',
#   'tiếng',
#   'việt',
#   'việt',
#   'sống',
#   'đài loan',
#   'nga'],
#  ['tiếng',
#   'việt',
#   'công ngôn ngữ',
#   'dân tộc thiểu',
#   'cộng',
#   'hòa',
#   'séc',
#   'việt',
#   'công dân tộc thiểu',
#   'séc'],
#  ['tiếng', 'địa phương'],
#  ['tiếng',
#   'việt',
#   'giọng',
#   'bắc nam',
#   'đột ngột',
#   'tiệm',
#   'tiến',
#   'dần',
#   'liền',
#   'giọng',
#   'bắc',
#   'giọng',
#   'trung huế',
#   'giọng',
#   'nam sài',
#   'gòn',
#   'phân tiếng',
#   'địa phương',
#   'giọng',
#   'điệu',
#   'địa phương',
#   'ngã',
#   'miền',
#   'bắc',
#   'miền',
#   'nam',
#   'trung miền',
#   'bắc',
#   'phụ âm',
#   'miền',
#   'nam',
#   'trung giọng',
#   'huế',
#   'giọng',
#   'địa phương',
#   'điển việt',
#   'bồ la',
#   'alexandre',
#   'de',
#   'rhodes',
#   'tiếng',
#   'miền',
#   'bắc',
#   'tảng',
#   'dictionarium',
#   'anamitico',
#   'latinum',
#   'pierre',
#   'pigneaux',
#   'de',
#   'béhaine',
#   'tiếng',
#   'miền',
#   'nam',
#   'tảng trang',
#   'thông đại sứ quán',
#   'việt nam',
#   'trung quốc',
#   'học giả',
#   'laurence thompson',
#   'đọc',
#   'tiêu chuẩn',
#   'dựa',
#   'giọng',
#   'hà nội nhiên',
#   'quy định',
#   'giọng',
#   'hà nội',
#   'chuẩn',
#   'quốc gia'],
#  ['ngữ', 'âm'],
#  ['nguyên âm'],
#  ['ngôn ngữ',
#   'đông nam',
#   'tiếng',
#   'việt',
#   'phong phú',
#   'nguyên âm',
#   'bảng',
#   'nguyên âm',
#   'giọng',
#   'hà nội'],
#  ['bảng',
#   'nguyên âm nguyên',
#   'âm nguyên',
#   'âm tròn',
#   'môi nguyên',
#   'âm tròn',
#   'môi',
#   'dạng',
#   'ngắn',
#   'a'],
#  ['tiếng', 'việt', 'hệ thống', 'nguyên âm', 'đôi', 'nguyên âm'],
#  ['phụ', 'âm'],
#  ['bảng', 'trình bày', 'phụ âm', 'tiếng', 'việt', 'viết'],
#  ['phụ âm', 'viết', 'viết', 'k thể', 'biểu diễn', 'c', 'k', 'q'],
#  ['phụ',
#   'âm tùy',
#   'địa phương biệt',
#   'phụ âm',
#   'miền',
#   'trình bày',
#   'kĩ',
#   'phương ngữ',
#   'tiếng',
#   'việt'],
#  ['điệu'],
#  ['tiếng',
#   'việt',
#   'ngôn ngữ điệu',
#   'âm tiết',
#   'tiếng',
#   'việt',
#   'điệu điệu',
#   'tiếng',
#   'việt',
#   'chữ',
#   'quốc ngữ',
#   'biểu thị',
#   'dấu',
#   'gọi',
#   'dấu',
#   'quen',
#   'gọi điệu',
#   'tiếng',
#   'việt',
#   'dấu biệt điệu',
#   'điệu trị',
#   'điệu phương ngôn',
#   'tiếng',
#   'việt điệu',
#   'gọi',
#   'đồng nghĩa phương ngôn',
#   'tiếng',
#   'việt phương ngôn',
#   'tiếng',
#   'việt',
#   'bắc',
#   'sáu',
#   'điệu phương ngôn',
#   'tiếng',
#   'việt',
#   'trung nam',
#   'điệu điệu',
#   'tiếng',
#   'việt',
#   'tiêu chuẩn',
#   'sáu',
#   'ngang',
#   'sắc',
#   'huyền ngã',
#   'quy định',
#   'phát',
#   'âm phương ngôn',
#   'tiếng',
#   'việt',
#   'phát âm',
#   'tiêu chuẩn',
#   'sáu',
#   'điệu'],
#  ['âm tiết',
#   'vần',
#   'nhập',
#   'tức',
#   'vần',
#   'kết thúc',
#   'phụ âm thể',
#   'sắc âm tắc',
#   'âm tiết',
#   'vần',
#   'nhập thể',
#   'điệu điệu trị',
#   'ngắn'],
#  ['thơ',
#   'ca điệu',
#   'phân',
#   'thành',
#   'hai',
#   'ngang',
#   'huyền trắc thể',
#   'thơ',
#   'cổ',
#   'đường',
#   'luật',
#   'lục bát',
#   'hòa',
#   'hợp điệu',
#   'trắc tiếng',
#   'câu thơ'],
#  ['ngữ', 'pháp'],
#  ['ngôn ngữ',
#   'đông nam',
#   'tiếng',
#   'việt',
#   'ngôn ngữ',
#   'đơn lập',
#   'quan hệ',
#   'ngữ pháp',
#   'thể hiện',
#   'chủ yếu',
#   'thông',
#   'hệ thống',
#   'hư',
#   'xếp',
#   'trật',
#   'câu',
#   'trật',
#   'thông dụng',
#   'tiếng',
#   'việt',
#   'chủ ngữ',
#   'vị ngữ',
#   'phụ ngữ'],
#  ['xếp',
#   'đứng',
#   'phụ',
#   'phụ',
#   'đứng',
#   'bổ sung',
#   'nghĩa',
#   'tương danh',
#   'đứng',
#   'đứng',
#   'bổ sung',
#   'nghĩa danh'],
#  ['tiếng',
#   'việt',
#   'hệ thống',
#   'đại nhân',
#   'xưng',
#   'phức tạp',
#   'dựa ngữ',
#   'quan hệ',
#   'thân',
#   'hệ thống',
#   'danh'],
#  ['vựng'],
#  ['vựng',
#   'tiếng',
#   'việt',
#   'chia',
#   'thành',
#   'hai',
#   'phận',
#   'việt mượn',
#   'hỗn chủng',
#   'kết',
#   'kết hợp',
#   'yếu tố',
#   'việt',
#   'ngoại lai'],
#  ['việt'],
#  ['việt',
#   'đời',
#   'tiếng',
#   'việt',
#   'biểu thị vật',
#   'hiện tượng',
#   'khái niệm',
#   'đời sống',
#   'hàng',
#   'tiếp xúc',
#   'ngôn ngữ',
#   'tày thái',
#   'việt',
#   'tương ứng',
#   'tiếng',
#   'định ngữ',
#   'âm ngữ',
#   'nghĩa'],
#  ['chín',
#   'sáu',
#   'việt',
#   'thông tục',
#   'tầng lớp',
#   'bình dân',
#   'ma quỷ',
#   'thần thánh',
#   'bắt',
#   'đi',
#   'miền',
#   'bắc',
#   'rụt',
#   'tằm',
#   'cột',
#   'nhẹ nhàng',
#   'cu',
#   'gái',
#   'miền',
#   'nam',
#   'đực',
#   'phát triển',
#   'dân trí',
#   'thông tục',
#   'dần'],
#  ['hán', 'việt'],
#  ['tiếp xúc',
#   'tiếng',
#   'việt',
#   'tiếng',
#   'hán',
#   'hán',
#   'trung quốc',
#   'xâm chiếm',
#   'việt trình',
#   'tiếp xúc',
#   'tiếng',
#   'việt',
#   'khối ngữ',
#   'tiếng',
#   'hán',
#   'giai đoạn',
#   'đầu',
#   'hiện tượng',
#   'diễn lẻ tẻ',
#   'rời rạc',
#   'chủ yếu',
#   'thông',
#   'đường',
#   'khẩu ngữ',
#   'tiếp xúc',
#   'việt',
#   'hán',
#   'lớp',
#   'gốc',
#   'hán',
#   'cổ hòa',
#   'lẫn',
#   'việt',
#   'đời',
#   'đường',
#   'tiếng',
#   'việt',
#   'tiếp ngữ',
#   'hán',
#   'hệ thống',
#   'đường',
#   'sách ngữ',
#   'gốc',
#   'hán',
#   'chủ yếu',
#   'đọc ngữ',
#   'âm đời',
#   'đường',
#   'tuân thủ',
#   'nguyên tắc ngữ âm',
#   'tiếng',
#   'việt',
#   'gọi',
#   'âm hán',
#   'việt',
#   'tiếng',
#   'việt',
#   'cạnh',
#   'mặt ngữ',
#   'âm hán',
#   'việt ngữ',
#   'nghĩa'],
#  ['hán',
#   'việt',
#   'chiếm',
#   'vốn',
#   'vựng',
#   'tiếng',
#   'việt',
#   'vai trò',
#   'hiện diện',
#   'lĩnh vực',
#   'đời sống',
#   'xã hội',
#   'việt',
#   'tầng lớp',
#   'trung lưu',
#   'trở hán',
#   'việt',
#   'sơn',
#   'thủy phong',
#   'phân biệt',
#   'bình dân',
#   'quê mùa',
#   'tiếng',
#   'việt',
#   'núi',
#   'gió nhiên',
#   'nổi tiếng',
#   'xu hướng',
#   'nghệ danh',
#   'hán',
#   'việt',
#   'báo chí',
#   'việt nam',
#   'gọi',
#   'kêu',
#   'mỹ nhật',
#   'kim lý',
#   'nhã kỳ',
#   'phan đinh tùng quang',
#   'lê',
#   'ngô kiến',
#   'huy'],
#  ['vận động',
#   'gìn',
#   'tiếng',
#   'việt',
#   'hán',
#   'việt',
#   'lọc',
#   'xu hướng',
#   'thay',
#   'việt thể',
#   'thư',
#   'gửi',
#   'hồ',
#   'mộ la',
#   'chín',
#   'chủ tịch',
#   'hồ',
#   'chí minh',
#   'viết',
#   'kêu minh',
#   'kêu',
#   'minh thúc',
#   'tiếng',
#   'ta',
#   'tiếng',
#   'ta',
#   'phổ thông',
#   'cháu',
#   'hồ',
#   'chí minh',
#   'đề xuất',
#   'thay',
#   'giám mã',
#   'ngựa'],
#  ['gốc', 'ấn', 'âu'],
#  ['việt nam',
#   'địa pháp',
#   'tiếng',
#   'pháp',
#   'ảnh hưởng',
#   'tiếng',
#   'việt ngữ',
#   'gốc pháp',
#   'thâm nhập',
#   'tiếng',
#   'việt',
#   'hán',
#   'việt',
#   'ảnh hưởng',
#   'tiếng',
#   'pháp văn',
#   'giấy tờ',
#   'giảng dạy',
#   'trường',
#   'sách báo',
#   'ảnh hưởng',
#   'kéo',
#   'gốc',
#   'pháp',
#   'lĩnh vực',
#   'khoa học kĩ thuật'],
#  ['thời kỳ',
#   'chiến tranh',
#   'việt nam',
#   'miền',
#   'bắc',
#   'việt nam',
#   'ảnh hưởng',
#   'liên xô',
#   'gốc',
#   'nga',
#   'kiện',
#   'du nhập',
#   'tiếng',
#   'việt',
#   'xô',
#   'viết',
#   'bôn sê',
#   'vích',
#   'thuật ngữ',
#   'khoa học kỹ thuật',
#   'tiếp xúc',
#   'hội nhập',
#   'sâu rộng',
#   'giới',
#   'tiếng',
#   'việt ngữ',
#   'gốc',
#   'tiếng'],
#  ['tiếng',
#   'việt',
#   'việt',
#   'hóa',
#   'mặt âm',
#   'đọc',
#   'đơn âm tiết',
#   'vay mượn',
#   'khẩu ngữ dàng',
#   'thâm nhập',
#   'tiếng',
#   'việt',
#   'hai',
#   'âm tiết',
#   'trở',
#   'vay mượn',
#   'thông sách',
#   'dấu ấn',
#   'ngoại lai',
#   'vay mượn',
#   'nguyên dạng',
#   'khăn',
#   'phát âm'],
#  ['gốc', 'tiếng', 'dân tộc thiểu'],
#  ['đa',
#   'sắc tộc',
#   'bốn',
#   'dân tộc',
#   'công tiếng',
#   'việt',
#   'phổ thông',
#   'tiếp tiếng',
#   'dân tộc thiểu',
#   'thông dụng',
#   'địa vật thể',
#   'vần phi',
#   'việt',
#   'trình diễn',
#   'suốt',
#   'chiều',
#   'lịch sử',
#   'nghiên cứu',
#   'kỹ',
#   'dựa',
#   'đăng tài',
#   'báo chí',
#   'địa phương',
#   'hành thể',
#   'chia thức',
#   'nhập',
#   'tiếng',
#   'dân tộc thiểu'],
#  ['tiếng',
#   'dân tộc',
#   'quảng bình',
#   'trở cư trú',
#   'đời',
#   'kinh văn',
#   'hóa',
#   'đông',
#   'mường tày',
#   'nùng thái',
#   'hán',
#   'việt',
#   'triệu đàm',
#   'cầm',
#   'đèo',
#   'địa danh',
#   'ghi âm',
#   'nậm',
#   'huổi',
#   'khuổi',
#   'pắc',
#   'đôi',
#   'giao lưu',
#   'kinh',
#   'hỗn hợp',
#   'hang',
#   'bua'],
#  ['hai',
#   'tiếng',
#   'h',
#   'mông',
#   'ghi âm hán',
#   'việt',
#   'mặc',
#   'tiếng',
#   'h',
#   'mông',
#   'quan hệ gũi',
#   'tiếng',
#   'hoa',
#   'ví dụ',
#   'vàng',
#   'giàng địa danh',
#   'lao',
#   'cai sa',
#   'pa',
#   'trường hợp',
#   'trừ',
#   'vua',
#   'mèo',
#   'hán việt',
#   'vương chí',
#   'sình',
#   'thể hiện',
#   'trang trọng'],
#  ['tiếng',
#   'dân tộc',
#   'tây nguyên',
#   'nam',
#   'ghi âm',
#   'đăk',
#   'lăk',
#   'krông',
#   'pắk biến',
#   'âm sóc',
#   'trăng nha',
#   'trang'],
#  ['chữ',
#   'vần',
#   'phi việt',
#   'viết',
#   'hướng',
#   'quyết định',
#   'hai',
#   'bốn',
#   'qđ',
#   'tiếng',
#   'việt',
#   'chữ',
#   'f j',
#   'w',
#   'z thể',
#   'tùy nghi'],
#  ['hỗn chủng'],
#  ['hỗn chủng',
#   'thành',
#   'yếu tố',
#   'gốc',
#   'yếu tố',
#   'việt hán',
#   'việt',
#   'yếu tố',
#   'việt',
#   'yếu tố',
#   'ấn âu',
#   'phát triển',
#   'tiếng',
#   'việt',
#   'hỗn chủng',
#   'đóng',
#   'vai trò',
#   'diễn',
#   'khái niệm',
#   'xã hội',
#   'hiện đại'],
#  ['ví dụ'],
#  ['vôi', 'hóa', 'vôi', 'việt', 'hóa', 'hán', 'việt'],
#  ['ôm', 'kế ôm', 'tiếng', 'đức', 'ohm kế', 'hán', 'việt'],
#  ['băng', 'việt', 'băng', 'tiếng', 'pháp', 'banque'],
#  ['game', 'thủ game', 'tiếng', 'thủ hán', 'việt'],
#  ['chữ viết'],
#  ['tiếng',
#   'việt',
#   'hệ',
#   'chữ viết',
#   'ký',
#   'latin',
#   'gọi',
#   'chữ',
#   'quốc ngữ',
#   'tài liệu',
#   'truyền giáo bồ',
#   'đào nha',
#   'chữ',
#   'quốc ngữ',
#   'phát triển',
#   'kỷ xvii',
#   'chuẩn định',
#   'công truyền',
#   'giáo pháp',
#   'alexandre',
#   'de',
#   'rhodes',
#   'in',
#   'dictionarium',
#   'annamiticum',
#   'lusitanum',
#   'et',
#   'latinum',
#   'sáu'],
#  ['xâm lăng',
#   'pháp kỷ',
#   'xix',
#   'chữ',
#   'quốc ngữ',
#   'trở thịnh hành',
#   'hầu văn',
#   'viết',
#   'thập niên',
#   'chín',
#   'hai',
#   'việt',
#   'hai',
#   'chữ viết',
#   'chữ',
#   'hán',
#   'chữ',
#   'nôm',
#   'chữ',
#   'nôm',
#   'tồn đầu',
#   'kỷ xx',
#   'công cụ',
#   'truyền tưởng',
#   'văn chương',
#   'tiếng',
#   'việt',
#   'chữ',
#   'nôm',
#   'thông dụng',
#   'việt nam'],
#  ['thư pháp'],
#  ['chữ',
#   'hán',
#   'chữ nhật',
#   'chữ',
#   'hàn',
#   'chữ viết',
#   'tiếng',
#   'việt',
#   'yêu',
#   'thư pháp',
#   'nâng',
#   'thành',
#   'nghệ thuật'],
#  ['thể',
#   'thư pháp',
#   'chữ',
#   'việt',
#   'viết',
#   'thư pháp',
#   'chữ',
#   'nôm',
#   'chữ',
#   'nôm',
#   'thay',
#   'chữ',
#   'quốc ngữ',
#   'nhu cầu treo',
#   'chữ',
#   'ta',
#   'khởi xướng',
#   'thư pháp',
#   'chữ',
#   'quốc ngữ'],
#  ['gõ', 'chữ', 'việt'],
#  ['thể',
#   'viết',
#   'chữ',
#   'việt',
#   'máy',
#   'gõ',
#   'tiếng',
#   'việt',
#   'mềm',
#   'soạn thảo văn',
#   'tiếng',
#   'việt',
#   'máy',
#   'phông',
#   'ký',
#   'chữ',
#   'quốc ngữ',
#   'cài',
#   'máy',
#   'gõ',
#   'tiếng',
#   'việt',
#   'quy định',
#   'phím',
#   'bấm',
#   'dấu',
#   'dấu',
#   'mũ',
#   'dấu móc',
#   'quy ước',
#   'chuẩn dấu',
#   'tiếng',
#   'việt mã',
#   'gõ',
#   'mềm mã',
#   'chữ',
#   'việt chuẩn',
#   'quốc tế',
#   'unicode',
#   'phổ biến'],
#  ['lề'],
#  ['bảy',
#   'nasa',
#   'tiếng',
#   'việt',
#   'bốn',
#   'ngôn ngữ',
#   'khắp',
#   'giới',
#   'liên lạc',
#   'hành tinh',
#   'ghi',
#   'đĩa',
#   'ghi',
#   'vàng',
#   'voyager',
#   'hai',
#   'tàu',
#   'voyager',
#   'voyager',
#   'hai'],
#  ['tác phẩm', 'phim ảnh', 'phụ đề', 'tiếng', 'việt', 'gọi', 'tắt', 'vietsub'],
#  [],
#  ['danh sách', 'ngôn ngữ'],
#  ['danh sách', 'ngôn ngữ'],
#  ['hệ thống', 'chữ nổi tiếng', 'việt'],
#  ['ngôn ngữ', 'ký hiệu', 'việt nam'],
#  ['liên kết'],
#  ['điển', 'việt', 'bồ la', 'alexandre', 'de', 'rhodes', 'mạng'],
#  ['điển',
#   'tiếng',
#   'việt',
#   'xưa',
#   'mạng',
#   'sách',
#   'sông',
#   'hương điển',
#   'việt',
#   'latinh',
#   'j',
#   'l',
#   'taberd điển',
#   'việt',
#   'bồ la',
#   'đại nam',
#   'quấc',
#   'âm vị'],
#  ['giáo sĩ', 'bồ đào', 'nha', 'chữ', 'quốc ngữ'],
#  ['gs',
#   'lâm văn',
#   'bé',
#   'sách',
#   'tiếng',
#   'việt',
#   'việt',
#   'học',
#   'thư viện',
#   'việt nam',
#   'hai',
#   'hai'],
#  ['ohio'],
#  ['ohio',
#   'tiểu bang',
#   'khu vực',
#   'trung tây',
#   'nằm',
#   'miền',
#   'đông',
#   'bắc',
#   'hoa',
#   'kỳ ohio',
#   'tiếng',
#   'iroquois nghĩa',
#   'sông',
#   'đẹp',
#   'dòng',
#   'sông',
#   'ranh giới',
#   'nam',
#   'tiểu bang',
#   'tiểu bang',
#   'kentucky'],
#  ['hải quân', 'hoa kỳ', 'tàu', 'ohio tỏ', 'trân trọng', 'tiểu bang'],
#  ['ây sinh',
#   'tổng thống',
#   'ulysses',
#   's',
#   'grant',
#   'rutherford',
#   'b',
#   'hayes',
#   'james',
#   'a',
#   'garfield',
#   'benjamin',
#   'harrison',
#   'william',
#   'mckinley',
#   'william',
#   'howard',
#   'taft',
#   'warren',
#   'g',
#   'harding'],
#  ['lịch sử'],
#  ['ohio', 'tiểu bang', 'chia', 'lãnh thổ', 'tây', 'bắc'],
#  ['kỷ', 'tám pháp', 'xây dựng', 'cửa khẩu', 'buôn', 'trao đổi', 'hàng', 'hóa'],
#  ['bảy',
#   'bốn',
#   'pháp',
#   'giao chiến',
#   'đất',
#   'mỹ',
#   'xung đột',
#   'quyền lợi chiến',
#   'gọi',
#   'chiến tranh pháp',
#   'da',
#   'hiệp ước',
#   'paris pháp',
#   'đành',
#   'quyền',
#   'quản lý',
#   'ohio'],
#  ['thông',
#   'tuyên ngôn',
#   'bảy',
#   'sáu',
#   'cấm',
#   'thực dân',
#   'mỹ',
#   'đừng',
#   'bố trí',
#   'ohio',
#   'quyền',
#   'kiểm soát',
#   'ohio',
#   'kết thúc',
#   'chiến thắng',
#   'mỹ mạng',
#   'mỹ'],
#  ['hoa',
#   'kỳ lãnh thổ tây',
#   'bắc',
#   'bảy',
#   'tám',
#   'bảy',
#   'ohio',
#   'nằm',
#   'lãnh thổ tây',
#   'bắc',
#   'lãnh thổ',
#   'indiana',
#   'ohio',
#   'chẩn',
#   'tiểu bang',
#   'lãnh thổ tây',
#   'bắc',
#   'đi',
#   'ohio cộng',
#   'nửa',
#   'diện tích',
#   'đông',
#   'đồng',
#   'michigan'],
#  ['sắc lệnh',
#   'tây bắc',
#   'ohio thể',
#   'tiểu bang',
#   'dân',
#   'sáu',
#   'chín',
#   'hai',
#   'tám',
#   'tổng thống',
#   'jefferson',
#   'ký',
#   'đạo luật',
#   'quốc hội',
#   'công ohio',
#   'tiểu bang',
#   'bảy',
#   'thông lệ',
#   'quốc hội',
#   'công bố',
#   'thức',
#   'quyền',
#   'tiểu bang',
#   'diễn',
#   'tận',
#   'tám',
#   'hai',
#   'louisiana',
#   'chín',
#   'tổng thống',
#   'eisenhower',
#   'ký',
#   'đạo luật',
#   'công bố',
#   'tám',
#   'thức',
#   'ohio',
#   'tiểu bang',
#   'mỹ'],
#  ['tám',
#   'ohio',
#   'chiến đấu',
#   'michigan chiến',
#   'đổ máu',
#   'thành phố',
#   'gargamesh chiến',
#   'gọi',
#   'chiến tranh',
#   'toledo'],
#  ['luật', 'pháp quyền'],
#  ['thủ phủ',
#   'ohio',
#   'columbus',
#   'trung tâm',
#   'tiểu bang',
#   'thống đốc',
#   'john kasich',
#   'hai',
#   'thượng nghị sĩ',
#   'liên bang',
#   'rob',
#   'portman',
#   'sherrod',
#   'brown'],
#  ['địa lý'],
#  ['sông',
#   'ohio',
#   'biên giới',
#   'nam ohio',
#   'đoạn',
#   'biên giới',
#   'bắc',
#   'tiểu bang',
#   'xác định',
#   'hồ',
#   'erie ngũ',
#   'đại hồ',
#   'ohio',
#   'tiếp giáp',
#   'pennsylvania',
#   'đông',
#   'michigan',
#   'bắc',
#   'indiana tây',
#   'kentucky',
#   'nam tây',
#   'virginia',
#   'đông',
#   'nam'],
#  ['ohio',
#   'đồng băng',
#   'xói mòn',
#   'trừ',
#   'phẳng tây',
#   'bắc',
#   'xưa',
#   'gọi',
#   'đầm',
#   'lầy',
#   'tối tăm',
#   'đất',
#   'băng',
#   'xói mòn',
#   'tây bắc',
#   'miền',
#   'trung ngăn',
#   'đông',
#   'đông',
#   'nam băng',
#   'xói mòn',
#   'nguyên allegheny',
#   'gọi',
#   'băng',
#   'xói mòn',
#   'nguyên',
#   'allegheny',
#   'ohio',
#   'đất',
#   'băng xói',
#   'mòn nguyên',
#   'allegheny',
#   'núi rừng',
#   'nhấp nhô'],
#  ['dòng',
#   'sông',
#   'tiểu bang thể',
#   'sông',
#   'miami',
#   'sông',
#   'scioto',
#   'sông',
#   'cuyahoga',
#   'sông',
#   'muskingum'],
#  ['kinh tế'],
#  ['ohio',
#   'tiểu bang',
#   'sản xuất',
#   'máy móc',
#   'công cụ',
#   'vật',
#   'tiểu bang',
#   'công nghiệp',
#   'ohio',
#   'nằm',
#   'khu vực',
#   'trồng',
#   'ngô mỹ',
#   'nông nghiệp',
#   'đóng',
#   'vai trò',
#   'kinh tế',
#   'tiểu bang',
#   'địa danh',
#   'lịch sử',
#   'thắng cảnh',
#   'hoạt động',
#   'giải trí',
#   'ohio tảng',
#   'ngành',
#   'du lịch',
#   'thịnh vượng',
#   'hai',
#   'hồ',
#   'bảy',
#   'kilômét',
#   'thắng cảnh',
#   'sông',
#   'thiên đường',
#   'du lịch',
#   'thuyền',
#   'đánh cá',
#   'đi',
#   'bơi',
#   'địa khảo cổ học',
#   'dân',
#   'da',
#   'bao mộ',
#   'địa thu hút',
#   'lịch sử'],
#  ['tổng sản phẩm',
#   'ohio',
#   'chín',
#   'chín',
#   'chín',
#   'sáu',
#   'hai',
#   'tỷ mỹ',
#   'kim đứng',
#   'bảy',
#   'toàn quốc',
#   'thu nhập',
#   'đầu',
#   'tiểu bang',
#   'hai',
#   'hai',
#   'tám',
#   'bốn',
#   'đứng',
#   'chín',
#   'sản phẩm',
#   'nông nghiệp',
#   'ohio',
#   'đậu nành',
#   'sản phẩm',
#   'sữa',
#   'ngô',
#   'cà chua',
#   'lợn',
#   'bò',
#   'gia cầm',
#   'trứng',
#   'sản phẩm',
#   'công nghiệp thiết',
#   'chuyên chở',
#   'sản phẩm',
#   'kim đúc',
#   'sẵn',
#   'máy móc',
#   'chế biến',
#   'đồ thiết',
#   'điện'],
#  ['dân'],
#  ['thống kê',
#   'dân',
#   'hai',
#   'dân',
#   'bốn',
#   'dân',
#   'bốn',
#   'bảy',
#   'trăm',
#   'chín',
#   'chín',
#   'thống kê',
#   'hai'],
#  ['tám', 'trăm', 'da', 'trắng'],
#  ['trăm', 'da', 'đen'],
#  ['chín', 'trăm', 'hispanic', 'latino'],
#  ['hai', 'trăm', 'mỹ', 'gốc', 'châu'],
#  ['hai', 'trăm', 'da'],
#  ['hai', 'trăm', 'gốc', 'hawaii đảo', 'thái bình dương'],
#  [],
#  ['tám', 'trăm', 'chủng tộc'],
#  ['bốn', 'trăm', 'máu', 'hỗn hợp'],
#  ['chủng tộc', 'đức', 'ailen mỹ', 'gốc', 'phi mỹ'],
#  ['sáu',
#   'sáu',
#   'trăm',
#   'dân',
#   'ohio',
#   'hai',
#   'bốn',
#   'trăm',
#   'tám',
#   'trăm',
#   'sáu',
#   'trở',
#   'nữ giới',
#   'chiếm',
#   'bốn',
#   'trăm',
#   'dân'],
#  ['giáo dục'],
#  ['trường', 'đại học'],
#  ['trường', 'đại học', 'công lập', 'trường', 'đại học', 'tiểu bang', 'ohio'],
#  ['hai', 'bốn', 'chi nhánh', 'trường', 'đại học', 'công lập', 'khu vực'],
#  ['bốn', 'sáu', 'trường', 'nghệ thuật'],
#  ['hai', 'trường', 'y tế', 'công'],
#  ['trường', 'cộng đồng'],
#  ['tám', 'trường', 'kỹ thuật'],
#  ['hai', 'bốn', 'trường', 'độc lập', 'phi lợi nhuận'],
#  ['danh sách', 'trường', 'đại học', 'ohio'],
#  ['liên kết'],
#  ['ohio', 'gov', 'website thức', 'phủ', 'tiểu bang', 'ohio'],
#  ['tối', 'pháp viện', 'ohio'],
#  ['hạ viện', 'ohio'],
#  ['thượng viện', 'ohio'],
#  ['đảng', 'dan', 'chủ', 'ohio'],
#  ['đảng', 'cộng', 'hòa', 'ohio'],
#  ['đài', 'ohio'],
#  ['california'],
#  ['california',
#   'việt',
#   'gọi',
#   'vắn tắt',
#   'ca',
#   'li',
#   'tiểu bang',
#   'ven',
#   'biển',
#   'tây',
#   'hoa',
#   'kỳ dân',
#   'tám',
#   'triệu',
#   'diện tích',
#   'bốn',
#   'km',
#   'california',
#   'tiểu bang',
#   'đông',
#   'dân',
#   'hoa kỳ',
#   'diện tích'],
#  ['địa lý'],
#  ['california',
#   'kề cận thái bình dương',
#   'oregon nevada',
#   'arizona',
#   'tiểu bang',
#   'baja',
#   'california',
#   'méxico',
#   'tiểu bang',
#   'cảnh nhiên',
#   'đẹp',
#   'bao',
#   'central valley',
#   'rộng rãi',
#   'núi',
#   'sa mạc',
#   'nóng nực',
#   'hàng',
#   'trăm',
#   'dặm',
#   'bờ',
#   'biển',
#   'đẹp',
#   'diện tích',
#   'bốn',
#   'km',
#   'tiểu bang',
#   'hoa',
#   'kỳ đức',
#   'việt nam',
#   'thành phố',
#   'tiểu bang',
#   'nằm',
#   'sát',
#   'bờ',
#   'biển',
#   'thái bình dương',
#   'los angeles',
#   'san francisco',
#   'san jose',
#   'long',
#   'beach',
#   'oakland',
#   'santa',
#   'ana',
#   'cam san',
#   'diego nhiên',
#   'thủ phủ',
#   'tiểu bang',
#   'sacramento',
#   'thành phố',
#   'nằm',
#   'thung lũng',
#   'trung tâm',
#   'trung tâm',
#   'địa lý',
#   'tiểu bang',
#   'bắc',
#   'fork',
#   'california'],
#  ['địa lý',
#   'california',
#   'phong phú',
#   'phức tạp',
#   'đa dạng',
#   'tiểu bang',
#   'thung lũng',
#   'trung tâm',
#   'thung lũng',
#   'màu mỡ',
#   'bao',
#   'quanh',
#   'dãy',
#   'núi',
#   'bờ',
#   'biển',
#   'tây',
#   'dãy',
#   'núi',
#   'granit',
#   'sierra',
#   'nevada',
#   'đông',
#   'dãy',
#   'núi',
#   'cascade',
#   'lửa',
#   'miền',
#   'bắc',
#   'dãy',
#   'núi',
#   'tehachapi',
#   'miền',
#   'nam',
#   'sông',
#   'đập',
#   'kênh',
#   'chảy',
#   'núi',
#   'tưới',
#   'thung lũng',
#   'trung tâm',
#   'tiểu bang',
#   'dự án',
#   'tiểu bang',
#   'cung',
#   'dự án',
#   'thung lũng',
#   'trung tâm',
#   'hệ thống',
#   'thành phố',
#   'chủ yếu',
#   'cung',
#   'tưới tiêu',
#   'nông nghiệp',
#   'nạo vét',
#   'sông',
#   'rộng',
#   'sâu',
#   'thành phố',
#   'nội địa',
#   'hải cảng',
#   'trung lũng',
#   'trung tâm',
#   'nóng nực',
#   'màu mỡ',
#   'trung tâm',
#   'nông nghiệp',
#   'california',
#   'trồng',
#   'lương thực',
#   'mỹ nhiên',
#   'trồng trọt',
#   'tàn phá',
#   'nhiệt độ',
#   'đông',
#   'mùa',
#   'đông',
#   'nam',
#   'thung lũng',
#   'sa mạc',
#   'gọi',
#   'thung lũng',
#   'san joaquin',
#   'chảy',
#   'sông',
#   'san joaquin',
#   'bắc',
#   'gọi',
#   'thung lũng',
#   'sacramento',
#   'chảy',
#   'sông',
#   'sacramento',
#   'châu thổ',
#   'vịnh',
#   'sacramento',
#   'san joaquin',
#   'cửa sông',
#   'hệ sinh thái',
#   'mặn',
#   'chủ yếu',
#   'dân cư',
#   'tiểu bang'],
#  ['dãy',
#   'núi',
#   'sierra',
#   'nevada',
#   'đông',
#   'trung tâm',
#   'tiểu bang',
#   'núi',
#   'whitney',
#   'đỉnh',
#   'núi',
#   'bốn',
#   'tám',
#   'tiểu bang',
#   'dãy',
#   'sierra',
#   'công viên',
#   'quốc gia',
#   'yosemite',
#   'hồ',
#   'tahoe',
#   'đông',
#   'dãy',
#   'sierra',
#   'thung lũng',
#   'owens',
#   'hồ',
#   'mono',
#   'sinh sống',
#   'chủ yếu',
#   'chim',
#   'biển',
#   'tây',
#   'hồ',
#   'clear',
#   'hồ',
#   'california',
#   'diện tích',
#   'mùa',
#   'đông',
#   'nhiệt độ',
#   'dãy',
#   'sierra',
#   'nevada',
#   'nhiệt độ',
#   'đóng băng',
#   'hàng',
#   'chục',
#   'dòng',
#   'sông',
#   'băng',
#   'sông',
#   'băng cực',
#   'nam',
#   'hoa kỳ',
#   'sông',
#   'băng',
#   'palisade'],
#  ['rừng',
#   'che phủ',
#   'trăm',
#   'tổng',
#   'diện tích',
#   'tiểu bang',
#   'california',
#   'thông',
#   'tiểu bang',
#   'diện tích',
#   'rừng',
#   'california',
#   'đứng',
#   'alaska',
#   'mặc',
#   'tỉ lệ',
#   'rừng',
#   'diện tích',
#   'tiểu bang',
#   'rừng',
#   'tây',
#   'bắc',
#   'tiểu bang',
#   'triền tây',
#   'dãy',
#   'sierra',
#   'nevada cánh',
#   'rừng',
#   'chủ yếu',
#   'sồi',
#   'dọc',
#   'dãy',
#   'núi',
#   'california',
#   'bờ',
#   'biển',
#   'đồi',
#   'chân',
#   'dãy',
#   'sierra',
#   'nevada',
#   'rừng',
#   'thông dãy',
#   'núi',
#   'san gabriel',
#   'san bernardino',
#   'miền',
#   'nam',
#   'california',
#   'núi',
#   'miền',
#   'trung san',
#   'diego'],
#  ['sa mạc',
#   'california',
#   'chiếm',
#   'hai',
#   'trăm',
#   'tổng',
#   'diện tích',
#   'miền',
#   'nam',
#   'dãy',
#   'núi',
#   'transverse',
#   'hồ',
#   'mặn',
#   'biển',
#   'salton',
#   'sa mạc',
#   'trung nam',
#   'gọi',
#   'mojave',
#   'đông nam',
#   'sa mạc',
#   'thung lũng',
#   'chết',
#   'badwater',
#   'flat',
#   'nóng',
#   'bắc mỹ',
#   'thung lũng',
#   'chết',
#   'đỉnh',
#   'núi',
#   'whitney',
#   'hai',
#   'hai',
#   'km',
#   'cố gắng',
#   'đi',
#   'kia',
#   'nổi tiếng',
#   'lee',
#   'bergthold hầu',
#   'miền',
#   'đông',
#   'nam',
#   'california',
#   'sa mạc',
#   'khô cằn',
#   'nóng',
#   'thung lũng',
#   'coachella',
#   'imperial',
#   'nhiệt độ',
#   'mùa',
#   'hè'],
#  ['nằm',
#   'bờ',
#   'biển',
#   'đông đúc',
#   'dân cư',
#   'california',
#   'khu vực',
#   'đô thị',
#   'bao',
#   'san jose',
#   'san francisco',
#   'oakland',
#   'los',
#   'angeles',
#   'long',
#   'beach',
#   'santa',
#   'ana',
#   'irvine',
#   'anaheim',
#   'san diego',
#   'thời tiết thái bình dương',
#   'ôn hòa',
#   'khí hậu',
#   'đất liền',
#   'nhiệt độ',
#   'đông',
#   'mùa',
#   'đông',
#   'nhiệt độ',
#   'hiếm độ',
#   'c'],
#  ['california động',
#   'đất',
#   'vết',
#   'đứt',
#   'gãy',
#   'vết',
#   'đứt',
#   'gãy',
#   'san',
#   'andreas',
#   'tiểu bang',
#   'alaska',
#   'washington',
#   'oregon',
#   'missouri',
#   'trận động',
#   'đất',
#   'động đất',
#   'california',
#   'xuyên',
#   'đông',
#   'dân cư'],
#  ['california',
#   'núi',
#   'lửa',
#   'hoạt động',
#   'núi',
#   'lửa',
#   'mammoth',
#   'núi',
#   'lửa',
#   'bao',
#   'đỉnh',
#   'lassen',
#   'phun',
#   'nham thạch',
#   'chín',
#   'bốn',
#   'chín',
#   'hai',
#   'núi',
#   'lửa',
#   'shasta'],
#  ['thành phố'],
#  ['tiểu bang',
#   'california',
#   'bốn',
#   'bảy',
#   'tám',
#   'thành phố',
#   'nằm',
#   'khu vực',
#   'đô thị',
#   'sáu',
#   'tám',
#   'trăm',
#   'dân cư',
#   'california',
#   'sống',
#   'hai',
#   'khu vực',
#   'đô thị',
#   'đại los',
#   'angeles',
#   'vịnh',
#   'san',
#   'francisco'],
#  ['dân', 'thành phố'],
#  ['los', 'angeles', 'sáu', 'chín', 'bốn', 'tám', 'hai'],
#  ['san', 'jose', 'tám', 'chín', 'bốn', 'chín', 'bốn'],
#  ['san francisco', 'bảy', 'bảy', 'sáu', 'bảy'],
#  ['san', 'diego', 'hai', 'hai', 'bốn'],
#  ['công viên', 'quốc gia'],
#  ['dịch vụ',
#   'vườn quốc gia',
#   'quản lý',
#   'công viên',
#   'quốc gia',
#   'california'],
#  ['đảo', 'alcatraz', 'san', 'francisco'],
#  ['đài', 'kỷ niệm', 'quốc gia', 'cabrillo', 'san', 'diego'],
#  ['đường mòn', 'california'],
#  ['công viên', 'quốc gia', 'quần đảo', 'eo biển', 'ventura'],
#  ['công viên', 'quốc gia', 'thung lũng', 'chết'],
#  ['đài', 'kỷ niệm', 'quốc gia', 'devils', 'postpile', 'mammoth', 'lakes'],
#  ['khu', 'tưởng niệm', 'eugene', 'o', 'neill', 'danville'],
#  ['pháo', 'đài', 'pointtại', 'presidio'],
#  ['khu', 'giải trí', 'quốc gia', 'cổng', 'vàng', 'san', 'francisco'],
#  ['khu', 'tưởng niệm', 'john', 'muir', 'martinez'],
#  ['công viên', 'quốc gia', 'joshua', 'tree', 'trụ sở', 'twentynine', 'palms'],
#  ['đường mòn', 'juan', 'bautista', 'de', 'anza'],
#  ['công viên', 'quốc gia', 'kings', 'canyon'],
#  ['công viên', 'quốc gia', 'núi', 'lửa', 'lassen', 'mineral'],
#  ['đài', 'kỷ niệm', 'quốc gia', 'lớp', 'dung nham', 'tulelake'],
#  ['trại giam', 'manzanar', 'independence'],
#  ['khu', 'bảo tồn', 'quốc gia', 'mojave', 'trụ sở', 'barstow'],
#  ['đài', 'kỷ niệm', 'quốc gia', 'muir', 'woods', 'thung lũng', 'mill'],
#  ['đường mòn', 'tây', 'ban nha', 'cũ'],
#  ['đài', 'kỷ niệm', 'quốc gia', 'pinnacles', 'paicines'],
#  ['bờ', 'biển', 'quốc gia', 'mũi', 'reyes', 'mũi', 'reyes'],
#  ['đường mòn', 'pony', 'express'],
#  ['đài',
#   'kỷ niệm',
#   'quốc gia',
#   'kho',
#   'đạn',
#   'hải quân',
#   'cảng',
#   'chicago',
#   'trạm',
#   'vũ khí',
#   'hải quân',
#   'concord'],
#  ['công viên', 'quốc gia', 'redwood'],
#  ['công viên',
#   'lịch sử',
#   'quốc gia',
#   'hậu phương',
#   'chiến tranh giới',
#   'hai',
#   'rosie',
#   'the',
#   'riveter',
#   'richmond'],
#  ['công viên', 'lịch sử', 'quốc gia', 'hàng hải', 'san', 'francisco'],
#  ['khu', 'giải trí', 'quốc gia', 'dãy', 'núi', 'santa', 'monica'],
#  ['công viên', 'quốc gia', 'củ tùng'],
#  ['khu', 'giải trí', 'quốc gia', 'whiskeytown', 'whiskeytown'],
#  ['công viên', 'quốc gia', 'yosemite'],
#  ['lịch sử'],
#  ['châu âu',
#   'california',
#   'đa dạng',
#   'văn hóa',
#   'ngôn ngữ',
#   'bắc',
#   'mỹ thời',
#   'thổ dân',
#   'bờ',
#   'biển',
#   'tây',
#   'hoa kỳ',
#   'săn',
#   'thú',
#   'biển',
#   'câu',
#   'cá hồi',
#   'thu',
#   'nhặt',
#   'tôm cua',
#   'dân tộc',
#   'động',
#   'california',
#   'đi',
#   'săn',
#   'thú',
#   'rừng',
#   'hái lượm',
#   'hạch',
#   'đầu mọng',
#   'dân tộc',
#   'california',
#   'hình thức',
#   'tổ chức',
#   'lạc',
#   'tiểu lạc',
#   'cộng đồng',
#   'bờ',
#   'biền dồi',
#   'tài nguyên',
#   'dân tộc',
#   'chumash',
#   'pomo',
#   'salinas',
#   'buôn hôn nhân dân tộc',
#   'liên minh',
#   'quân',
#   'dân tộc',
#   'liên hệ',
#   'xã hội',
#   'kinh tế'],
#  ['joão',
#   'rodrigues',
#   'cabrilho bồ',
#   'đào nha',
#   'châu âu',
#   'thám hiểm',
#   'bờ',
#   'biển',
#   'california',
#   'bốn',
#   'hai',
#   'francis',
#   'drake',
#   'thám hiểm',
#   'bờ',
#   'biển',
#   'tuyên bố',
#   'chủ quyền',
#   'đất',
#   'bảy',
#   'chín',
#   'kỷ tám',
#   'hội',
#   'truyền giáo tây',
#   'ban nha',
#   'xây dựng',
#   'làng',
#   'đất trợ',
#   'khổng lồ',
#   'miền',
#   'rộng rãi',
#   'bắc',
#   'baja',
#   'california'],
#  ['ban đầu',
#   'đất',
#   'california',
#   'bao tây',
#   'bắc',
#   'đế quốc tây',
#   'ban nha',
#   'tức',
#   'đảo',
#   'baja',
#   'california',
#   'đất',
#   'tiểu bang',
#   'california',
#   'nevada',
#   'utah',
#   'arizona',
#   'wyoming',
#   'gọi',
#   'alta',
#   'california',
#   'thời kỳ',
#   'đầu',
#   'ranh giới',
#   'biển',
#   'cortez',
#   'bờ',
#   'biển',
#   'thái bình dương',
#   'thám hiểm',
#   'california',
#   'vẽ',
#   'hòn',
#   'đảo',
#   'thời',
#   'california',
#   'hòn',
#   'đảo',
#   'lạc viên',
#   'california',
#   'las',
#   'sergas',
#   'de',
#   'esplandián',
#   'tiểu thuyết',
#   'tiếng',
#   'tây',
#   'ban nha',
#   'garci',
#   'rodríguez',
#   'de',
#   'montalvo',
#   'viết',
#   'kỷ',
#   'sáu'],
#  ['đất',
#   'thổ dân',
#   'thám hiểm',
#   'lác đác',
#   'châu âu kỷ',
#   'sáu',
#   'kỷ tám',
#   'tây',
#   'ban nha',
#   'chiếm',
#   'thành',
#   'địa mexico',
#   'giành',
#   'độc lập',
#   'chiến tranh',
#   'độc lập',
#   'mexico',
#   'california',
#   'thành',
#   'hai',
#   'mexico',
#   'giành',
#   'độc lập',
#   'california',
#   'tỉnh',
#   'miền',
#   'bắc',
#   'quốc gia',
#   'trại',
#   'nuôi',
#   'bò',
#   'gọi',
#   'rancho',
#   'chế độ',
#   'california',
#   'mexico',
#   'thương gia',
#   'thực dân',
#   'hoa kỳ',
#   'báo hiệu',
#   'quyết liệt',
#   'khắp',
#   'miền',
#   'california'],
#  ['thời kỳ',
#   'quý tộc',
#   'nga',
#   'thử',
#   'thám hiểm',
#   'tuyên bố',
#   'chủ quyền',
#   'california',
#   'thám hiểm',
#   'thành công',
#   'sa hoàng',
#   'phủ',
#   'mexico',
#   'xây dựng',
#   'pháo đài',
#   'chặn',
#   'xâm nhập',
#   'miền',
#   'california',
#   'sinh sống',
#   'y học',
#   'hiện trừ',
#   'bùng nổ',
#   'bệnh',
#   'sốt',
#   'vàng',
#   'sốt rét',
#   'dịch',
#   'hạch',
#   'muỗi bọ',
#   'chét',
#   'loài',
#   'giết',
#   'chết',
#   'đông',
#   'cứng',
#   'california'],
#  ['mexico',
#   'giành',
#   'độc lập',
#   'tây ban',
#   'nha hội',
#   'truyền giáo tây',
#   'ban nha',
#   'california',
#   'phủ',
#   'mexico',
#   'vội vàng',
#   'giải tán',
#   'bãi',
#   'hội nhiên',
#   'thành phố',
#   'california',
#   'phát triển',
#   'xung quanh',
#   'hội',
#   'truyền giáo',
#   'thành phố',
#   'thánh thí dụ',
#   'los',
#   'angeles đức',
#   'maria san',
#   'francisco',
#   'thánh phanxicô',
#   'thành',
#   'assisi',
#   'san',
#   'jose',
#   'thánh giuse',
#   'san',
#   'diego',
#   'thánh điđacô'],
#  ['chiến tranh',
#   'mỹ mexico',
#   'dân mỹ',
#   'nổi',
#   'chống',
#   'phủ',
#   'mexico',
#   'chiến tám',
#   'bốn',
#   'sáu',
#   'cộng',
#   'hòa',
#   'california',
#   'thành lập',
#   'cờ',
#   'gấu tung',
#   'bay',
#   'lá',
#   'cờ',
#   'hình gấu',
#   'vàng nhiên',
#   'cộng hòa',
#   'chấm dứt',
#   'đột ngột',
#   'tướng',
#   'john d',
#   'sloat',
#   'hải quân',
#   'hoa',
#   'kỳ tiến',
#   'vịnh',
#   'san francisco',
#   'tuyên bố',
#   'chủ quyền',
#   'hoa kỳ',
#   'california',
#   'chiến tranh',
#   'california',
#   'chia',
#   'thành',
#   'hai',
#   'mexico',
#   'hoa kỳ',
#   'bắc',
#   'gọi',
#   'alta',
#   'california',
#   'tiểu bang',
#   'california',
#   'hoa',
#   'kỳ nam',
#   'mexico',
#   'chia',
#   'thành',
#   'hai',
#   'tiểu bang',
#   'baja',
#   'california',
#   'baja',
#   'california',
#   'sur'],
#  ['tám',
#   'bốn',
#   'tám',
#   'bốn',
#   'tây',
#   'ban nha',
#   'thượng california',
#   'vàng',
#   'phát',
#   'hiệm',
#   'sacramento',
#   'mỹ âu châu',
#   'hy vọng',
#   'vàng',
#   'đổ xô',
#   'vàng',
#   'california',
#   'tám',
#   'bốn',
#   'chín',
#   'nhập cư',
#   'miền',
#   'california',
#   'tiểu bang',
#   'hoa kỳ',
#   'tám',
#   'tiểu bang',
#   'gia nhập',
#   'liên bang',
#   'coi',
#   'tiểu bang',
#   'tức',
#   'cấm',
#   'chế độ',
#   'nô lệ'],
#  ['đi',
#   'miền',
#   'tây',
#   'trung tâm',
#   'miền',
#   'đông',
#   'tốn',
#   'nguy hiểm',
#   'hành',
#   'đi',
#   'chuyến',
#   'đường biển',
#   'đi',
#   'xe ngựa',
#   'đi',
#   'khăn',
#   'đường đất',
#   'tám',
#   'sáu',
#   'chín',
#   'đường',
#   'xe lửa',
#   'xuyên',
#   'lục địa',
#   'hoàn thành',
#   'lối',
#   'đi',
#   'thẳng',
#   'hàng',
#   'trăm ngàn',
#   'mỹ california',
#   'khám phá',
#   'tưới',
#   'đất',
#   'hè',
#   'khô',
#   'cạn',
#   'đất',
#   'hợp',
#   'trồng',
#   'nông nghiệp',
#   'cam quýt',
#   'trồng',
#   'phổ biến',
#   'ngành',
#   'sản xuất',
#   'nông nghiệp',
#   'california',
#   'thành công'],
#  ['đầu',
#   'kỷ hai',
#   'di trú',
#   'california',
#   'hoàn thành',
#   'đường',
#   'xuyên',
#   'lục địa',
#   'đường',
#   'lincoln lộ',
#   'sáu',
#   'sáu',
#   'chín',
#   'chín',
#   'sáu',
#   'dân',
#   'california',
#   'triệu',
#   'california',
#   'tiểu bang',
#   'đông',
#   'dân',
#   'liên bang',
#   'chín',
#   'sáu',
#   'nhân khẩu',
#   'tiểu bang',
#   'california',
#   'địa giới',
#   'tiểu bang',
#   'khuynh hướng',
#   'kỹ thuật',
#   'văn hóa',
#   'trung tâm',
#   'quốc tế',
#   'công ty',
#   'kỹ thuật',
#   'ngành',
#   'công nghiệp',
#   'điện ảnh',
#   'truyền hình',
#   'công nghiệp',
#   'âm nhạc',
#   'ngành',
#   'sản xuất',
#   'nông nghiệp'],
#  ['nhân khẩu'],
#  ['dân'],
#  ['hai',
#   'sáu',
#   'california',
#   'sáu',
#   'hai',
#   'bốn',
#   'bảy',
#   'hai',
#   'chín',
#   'chín',
#   'tám',
#   'trăm',
#   'hai',
#   'hai',
#   'hai',
#   'sáu',
#   'bốn',
#   'chín',
#   'bốn',
#   'sáu',
#   'bảy',
#   'trăm',
#   'hai',
#   'tỷ lệ',
#   'california',
#   'đứng',
#   'hàng',
#   'tiểu bang',
#   'dân',
#   'bảy',
#   'hai',
#   'trưởng nhiên',
#   'bảy',
#   'bốn',
#   'chín',
#   'nhập cư',
#   'california',
#   'tiểu bang',
#   'đông',
#   'dân',
#   'hai',
#   'trăm',
#   'mỹ sống',
#   'quốc gia',
#   'california',
#   'đông',
#   'dân',
#   'bốn',
#   'giới',
#   'california',
#   'canada',
#   'bốn triệu',
#   'dân'],
#  ['chủng tộc'],
#  ['sắc tộc',
#   'chiếm',
#   'đa california',
#   'tiểu bang thiểu',
#   'da',
#   'trắng',
#   'da',
#   'trắng',
#   'gốc',
#   'châu mỹ',
#   'latinh',
#   'đông',
#   'chiếm',
#   'đại đa',
#   'gốc',
#   'châu mỹ',
#   'latinh',
#   'chiếm',
#   'dân mỹ',
#   'gốc',
#   'mỹ',
#   'gốc',
#   'phi',
#   'thổ dân',
#   'da'],
#  ['nhập cư',
#   'châu mỹ',
#   'latinh',
#   'méxico',
#   'tỉ lệ',
#   'sinh sản',
#   'gốc',
#   'châu mỹ',
#   'latinh',
#   'nghiên cứu',
#   'đoán',
#   'chiếm',
#   'đa',
#   'hai',
#   'bốn',
#   'california',
#   'tỉ lệ',
#   'gốc',
#   'châu nhì',
#   'toàn quốc',
#   'hawaii'],
#  ['ngôn ngữ'],
#  ['hai',
#   'california',
#   'trở tiếng',
#   'tiếng',
#   'tây',
#   'ban nha',
#   'lượt',
#   'sáu',
#   'trăm',
#   'hai',
#   'tám',
#   'trăm',
#   'tiếng',
#   'trung quốc',
#   'đứng',
#   'hai',
#   'sáu',
#   'trăm',
#   'tiếng',
#   'tagalog',
#   'tiếng',
#   'việt'],
#  ['ngôn ngữ',
#   'thổ dân',
#   'mai',
#   'chín',
#   'tám',
#   'sáu',
#   'hiến pháp',
#   'california định tiếng',
#   'ngôn ngữ',
#   'phổ thông thức',
#   'tiểu bang'],
#  ['tôn giáo'],
#  ['dân', 'california', 'tôn giáo'],
#  ['kitô giáo', 'bảy', 'trăm'],
#  ['lành', 'tám', 'trăm'],
#  ['baptist', 'tám', 'trăm'],
#  ['trưởng', 'lão', 'trăm'],
#  ['giám lý', 'hai', 'trăm'],
#  ['giáo hội', 'luther', 'hai', 'trăm'],
#  ['giáo hội', 'kháng', 'hai', 'trăm'],
#  ['giáo hội', 'công giáo', 'rôma', 'bốn', 'trăm'],
#  ['giáo phái', 'kitô', 'trăm'],
#  ['thái giáo', 'hai', 'trăm'],
#  ['hồi giáo', 'hai', 'trăm'],
#  ['tôn giáo', 'trăm'],
#  ['tôn giáo', 'hai', 'trăm'],
#  ['tiểu bang', 'miền', 'tây', 'tôn giáo', 'hoa kỳ'],
#  ['kinh tế'],
#  ['tiểu bang',
#   'tiếng',
#   'thái độ',
#   'thoải mái',
#   'sánh',
#   'tiểu bang',
#   'bờ',
#   'biển',
#   'đông',
#   'hoa kỳ',
#   'kinh tế',
#   'california',
#   'sáu giới',
#   'đóng góp',
#   'trăm',
#   'tổng sản phẩm',
#   'quốc nội',
#   'hoa kỳ',
#   'ngành',
#   'công nghiệp',
#   'tiểu bang',
#   'bao',
#   'nông nghiệp',
#   'hàng',
#   'vũ trụ',
#   'giải trí',
#   'công nghiệp nhẹ',
#   'du lịch',
#   'california',
#   'trung tâm',
#   'kinh tế',
#   'hollywood',
#   'thung lũng',
#   'trung tâm',
#   'california',
#   'thung lũng',
#   'silicon',
#   'rượu',
#   'vang'],
#  ['phủ'],
#  ['phủ',
#   'liên bang',
#   'hoa',
#   'kỳ california',
#   'phủ',
#   'kiểu',
#   'cộng',
#   'hòa',
#   'nhánh',
#   'phủ',
#   'hành pháp',
#   'thống đốc',
#   'california',
#   'quan chức',
#   'bầu rẽ',
#   'lập pháp',
#   'hạ viện',
#   'thượng viện',
#   'tư pháp',
#   'tòa án',
#   'tối',
#   'california',
#   'tòa',
#   'tiểu bang',
#   'cử tri',
#   'tham gia',
#   'trình',
#   'phủ',
#   'kiến nghị',
#   'trưng cầu dân',
#   'bãi miễn',
#   'phê chuẩn'],
#  ['giáo dục'],
#  ['tu án',
#   'hiến pháp',
#   'tiểu bang',
#   'california',
#   'chi phí',
#   'bốn',
#   'trăm',
#   'thu nhập',
#   'tiểu bang',
#   'hệ thống',
#   'trường',
#   'công california',
#   'tiểu bang',
#   'khoản'],
#  ['trường',
#   'tiểu học',
#   'công lập',
#   'chất',
#   'tùy',
#   'trường',
#   'chất trường',
#   'địa phương',
#   'tùy',
#   'tiền',
#   'thuế',
#   'đấy',
#   'cỡ',
#   'ban',
#   'phụ trách',
#   'trường',
#   'chi phí',
#   'quản lý',
#   'tốn',
#   'tiền',
#   'giáo dục',
#   'nghèo',
#   'tỷ lệ',
#   'đọc',
#   'viết thể',
#   'bảy',
#   'trăm',
#   'dân cư'],
#  ['hệ thống',
#   'trường',
#   'trung học',
#   'công lập',
#   'dạy',
#   'lớp',
#   'tùy',
#   'nghề nghiệp',
#   'ngôn ngữ',
#   'khoa học',
#   'nhân văn',
#   'học sinh',
#   'giỏi',
#   'sinh viên',
#   'tương lai',
#   'học sinh',
#   'công nghiệp',
#   'học sinh',
#   'bốn',
#   'tám',
#   'phủ',
#   'ngừng',
#   'đòi',
#   'đi',
#   'học',
#   'sáu',
#   'khu vực',
#   'trường học',
#   'trường',
#   'trung học sở',
#   'lớp',
#   'tùy',
#   'chương trình',
#   'học',
#   'đi',
#   'trường học',
#   'trường',
#   'tiểu học',
#   'dạy học',
#   'lịch sử',
#   'xã hội trường',
#   'mẫu giáo tùy',
#   'nửa phủ',
#   'đòi',
#   'trẻ',
#   'trường',
#   'sáu'],
#  ['hệ thống',
#   'viện',
#   'đại học',
#   'nghiên cứu',
#   'tiểu bang',
# ...
#   'marilyn',
#   'monroe',
#   'khuôn mặt',
#   'biểu tượng',
#   'sản xuất',
#   'phim',
#   'kiêm',
#   'kinh doanh',
#   'walt',
#   'disney',
#   'đi',
#   'đầu',
#   'lĩnh vực',
#   'phim hoạt hình',
#   'phim ảnh',
#   'quảng cáo',
#   'sản phẩm'],
#  ['chín',
#   'bảy',
#   'đạo diễn',
#   'phim',
#   'martin',
#   'scorsese',
#   'francis',
#   'ford',
#   'coppola',
#   'robert',
#   'altman',
#   'thành',
#   'gọi',
#   'tân hollywood',
#   'hollywood phục',
#   'hưng phim',
#   'kinh điển',
#   'chẳng hạn',
#   'the',
#   'godfather'],
#  ['phim',
#   'trường hollywood',
#   'sản xuất',
#   'phim',
#   'thương mại',
#   'thành công',
#   'giới',
#   'star',
#   'wars',
#   'titanic',
#   'sản phẩm',
#   'hollywood',
#   'chiếm lĩnh',
#   'công nghệ',
#   'điện ảnh',
#   'giới',
#   'giải oscar',
#   'giải thưởng',
#   'điện ảnh',
#   'uy tín giới',
#   'tổ chức',
#   'hàng',
#   'viện hàn lâm',
#   'khoa học',
#   'nghệ thuật',
#   'điện ảnh',
#   'chín',
#   'hai',
#   'chín'],
#  ['mỹ',
#   'nghiện truyền hình giới',
#   'trung bình',
#   'truyền hình',
#   'hai',
#   'sáu',
#   'bốn',
#   'hệ thống',
#   'truyền hình',
#   'truyền hình',
#   'thương mại',
#   'tỷ lệ',
#   'sở hữu',
#   'tv',
#   'hộ',
#   'gia đình',
#   'chín',
#   'sáu',
#   'bảy',
#   'trăm',
#   'bốn',
#   'đài truyền hình',
#   'hoa kỳ',
#   'nbc',
#   'cbs',
#   'abc',
#   'fox',
#   'mỹ lắng',
#   'chương trình',
#   'radio',
#   'thương mại',
#   'hóa',
#   'trung bình',
#   'hai',
#   'tiếng',
#   'rưỡi',
#   'tờ',
#   'báo',
#   'nổi tiếng',
#   'hoa kỳ',
#   'bao',
#   'the',
#   'wall',
#   'street',
#   'journal',
#   'the',
#   'new',
#   'york',
#   'times',
#   'usa',
#   'today',
#   'cổng',
#   'trang',
#   'mạng trang',
#   'kiếm',
#   'mạng',
#   'trang mạng',
#   'phổ biến',
#   'google',
#   'facebook',
#   'youtube',
#   'twitter',
#   'instagram',
#   'wikipedia',
#   'ebay',
#   'amazon',
#   'com',
#   'reddit',
#   'yahoo',
#   'netflix',
#   'pornhub'],
#  ['hai', 'bảy', 'mười', 'hai', 'triệu', 'mỹ', 'viết', 'blog'],
#  ['nhạc',
#   'nhịp điệu',
#   'trữ',
#   'tình mỹ',
#   'gốc',
#   'châu phi',
#   'ảnh hưởng',
#   'sâu',
#   'đậm âm nhạc',
#   'mỹ biệt',
#   'âm nhạc',
#   'truyền thống',
#   'châu âu',
#   'làn điệu',
#   'nhạc',
#   'cổ truyền',
#   'nhạc',
#   'blues nhạc',
#   'old time',
#   'music',
#   'thu thập',
#   'âm nhạc',
#   'bình dân',
#   'thưởng thức',
#   'khắp',
#   'giới',
#   'nhạc jazz',
#   'phát triển',
#   'âm nhạc',
#   'louis',
#   'armstrong',
#   'duke',
#   'ellington',
#   'đầu',
#   'kỷ xx',
#   'nhạc',
#   'đồng quê',
#   'rhythm and',
#   'blues rock',
#   'and roll',
#   'thập niên',
#   'chín',
#   'hai',
#   'thập niên',
#   'chín',
#   'nổi tiếng',
#   'chẳng hạn',
#   'elvis',
#   'presley',
#   'mỹ funk',
#   'hip',
#   'hop nhạc',
#   'pop mỹ',
#   'michael',
#   'jackson mệnh danh hoàng',
#   'nhạc',
#   'pop madonna',
#   'mệnh danh',
#   'nữ',
#   'hoàng nhạc',
#   'pop',
#   'ca sĩ',
#   'taylor',
#   'swift',
#   'britney',
#   'spears',
#   'katy',
#   'perry',
#   'beyoncé',
#   'jay',
#   'z',
#   'eminem',
#   'huyền thoại',
#   'âm nhạc'],
#  ['văn chương', 'triết học', 'kiến trúc', 'nghệ thuật'],
#  ['kỷ',
#   'xviii',
#   'đầu',
#   'kỷ xix',
#   'văn chương',
#   'nghệ thuật',
#   'mỹ',
#   'ảnh hưởng',
#   'đậm nét',
#   'châu âu văn',
#   'nathaniel',
#   'hawthorne',
#   'edgar',
#   'allan',
#   'poe',
#   'henry',
#   'david',
#   'thoreau',
#   'lập',
#   'văn chương',
#   'mỹ rệt',
#   'kỷ xix',
#   'mark',
#   'twain',
#   'thơ',
#   'walt',
#   'whitman',
#   'gương mặt',
#   'nửa kỷ',
#   'emily',
#   'dickinson',
#   'suốt',
#   'đời',
#   'công thơ',
#   'mỹ mười',
#   'hai',
#   'công dân',
#   'hoa',
#   'kỳ đoạt',
#   'giải',
#   'nobel',
#   'văn chương',
#   'bob',
#   'dylan',
#   'hai',
#   'sáu',
#   'ernest',
#   'hemingway',
#   'đoạt',
#   'giải',
#   'nobel',
#   'chín',
#   'bốn',
#   'coi văn',
#   'ảnh hưởng',
#   'kỷ xx',
#   'tác phẩm',
#   'đọng',
#   'khía cạnh',
#   'kinh nghiệm',
#   'đặc',
#   'quốc gia',
#   'moby',
#   'dick',
#   'herman',
#   'melville',
#   'phiêu lưu',
#   'huckleberry',
#   'finn',
#   'đại văn hào',
#   'mark',
#   'twain',
#   'giết',
#   'húng nhại',
#   'harper',
#   'lee',
#   'đại gia',
#   'gatsby',
#   'f',
#   'scott',
#   'fitzgerald thể',
#   'tặng',
#   'danh hiệu',
#   'đại tiểu thuyết',
#   'mỹ thể',
#   'văn chương',
#   'bình dân',
#   'văn chương',
#   'miền',
#   'tây',
#   'tiểu thuyết',
#   'tội phạm',
#   'phát triển',
#   'hoa kỳ'],
#  ['thuyết',
#   'tiên nghiệm',
#   'ralph',
#   'waldo',
#   'emerson',
#   'thoreau',
#   'khởi xướng',
#   'thiết lập',
#   'phong trào',
#   'triết học',
#   'mỹ',
#   'nội chiến',
#   'hoa kỳ',
#   'charles',
#   'sanders',
#   'pierce',
#   'william',
#   'james',
#   'john',
#   'dewey',
#   'tiên phong',
#   'phát triển',
#   'chủ nghĩa thực dụng',
#   'kỷ xx',
#   'công trình',
#   'willard',
#   'van',
#   'orman',
#   'quine',
#   'richard',
#   'rorty',
#   'giúp',
#   'triết học',
#   'phân tích',
#   'trở',
#   'nổi bật',
#   'triết học',
#   'mỹ'],
#  ['nghệ thuật',
#   'thị giác',
#   'trường phái',
#   'sông',
#   'hudson',
#   'phong trào',
#   'kỷ xix',
#   'truyền thống',
#   'chủ nghĩa nhiên',
#   'châu âu',
#   'chương trình',
#   'armory',
#   'chín',
#   'thành phố',
#   'new',
#   'york',
#   'triển lãm',
#   'nghệ thuật',
#   'đương đại',
#   'châu âu sốt',
#   'công góp',
#   'nghệ thuật',
#   'hoa kỳ',
#   'georgia',
#   'o',
#   'keefe',
#   'marsden',
#   'hartley',
#   'thử nghiệm',
#   'phong hướng',
#   'phong trào',
#   'mỹ thuật',
#   'chủ nghĩa biểu hiện',
#   'trừu tượng',
#   'jackson',
#   'pollack',
#   'willem',
#   'de',
#   'kooning',
#   'nghệ thuật',
#   'văn hóa',
#   'dân gian',
#   'andy',
#   'warhol',
#   'roy lichtenstein',
#   'phát triển',
#   'rộng',
#   'khắp',
#   'hoa kỳ',
#   'làn sóng',
#   'chủ nghĩa',
#   'hiện đại chủ nghĩa hậu',
#   'hiện đại',
#   'kiến trúc sư',
#   'mỹ frank',
#   'lloyd',
#   'wright',
#   'philip',
#   'johnson',
#   'frank',
#   'gehry',
#   'đỉnh',
#   'lĩnh vực'],
#  ['lừng danh',
#   'phát triển thể',
#   'kịch',
#   'mỹ bầu',
#   'p',
#   't',
#   'barnum',
#   'khởi đầu',
#   'hành hát',
#   'hạ manhattan',
#   'tám',
#   'bốn',
#   'kịch',
#   'đoàn harrigan',
#   'and hart',
#   'dàn',
#   'dựng loạt',
#   'nhạc',
#   'hài kịch',
#   'thu hút',
#   'đông',
#   'công new',
#   'york',
#   'thập niên',
#   'tám',
#   'bảy',
#   'kỷ xx',
#   'hình thức',
#   'nhạc kịch',
#   'hiện đại',
#   'sân khấu',
#   'broadway nhạc',
#   'soạn nhạc',
#   'kịch',
#   'irving berlin',
#   'cole',
#   'porter',
#   'stephen',
#   'sondheim',
#   'tiêu chuẩn thể',
#   'nhạc văn hóa',
#   'dân gian',
#   'soạn kịch',
#   'eugene o',
#   'neill',
#   'đoạt',
#   'giải',
#   'nobel',
#   'văn chương',
#   'chín',
#   'sáu',
#   'soạn kịch',
#   'nổi danh',
#   'hoa',
#   'kỳ đoạt',
#   'giải',
#   'pulitzer',
#   'tennessee',
#   'williams',
#   'edward',
#   'albee',
#   'august',
#   'wilson'],
#  ['mặc',
#   'coi',
#   'nhẹ',
#   'đương thời',
#   'công trình',
#   'charles',
#   'ives',
#   'thập niên',
#   'chín',
#   'thành',
#   'soạn',
#   'nhạc',
#   'hoa kỳ thể',
#   'nhạc',
#   'truyền thống',
#   'cổ điển',
#   'tiếp',
#   'henry',
#   'cowell',
#   'john cage',
#   'tiến tác nhạc',
#   'cổ điển',
#   'màu sắc',
#   'mỹ aaron',
#   'copland',
#   'george gershwin',
#   'phát triển',
#   'thể nhạc',
#   'cổ điển',
#   'bình dân',
#   'tổng hợp',
#   'biệt mỹ',
#   'biên đạo',
#   'múa',
#   'isadora',
#   'duncan',
#   'martha',
#   'graham',
#   'gương mặt',
#   'tiêu biểu',
#   'khiêu vũ',
#   'hiện đại',
#   'george',
#   'balanchine',
#   'jerome',
#   'robbins',
#   'đi',
#   'đầu',
#   'múa',
#   'balê kỷ',
#   'xx'],
#  ['kiến trúc',
#   'hoa kỳ',
#   'ảnh hưởng',
#   'phong kiến trúc',
#   'khắp giới',
#   'kiến trúc',
#   'hoa kỳ',
#   'chủ yếu',
#   'phong',
#   'hiện đại',
#   'thể hiện',
#   'tòa',
#   'chọc trời',
#   'xây',
#   'kỷ',
#   'hai'],
#  ['hoa kỳ',
#   'đi',
#   'đầu',
#   'lĩnh vực',
#   'nghệ thuật',
#   'nhiếp ảnh',
#   'hiện đại',
#   'nhiếp ảnh',
#   'alfred',
#   'steiglitz',
#   'edward',
#   'steichen',
#   'ansel',
#   'adams',
#   'truyện',
#   'tranh kỳ',
#   'báo',
#   'gọi',
#   'comic',
#   'strip',
#   'sách',
#   'truyện tranh',
#   'hai',
#   'mỹ superman',
#   'hãng',
#   'dc',
#   'comics',
#   'captain',
#   'america',
#   'hãng',
#   'truyện tranh',
#   'marvel',
#   'siêu hùng',
#   'sách',
#   'truyện tranh',
#   'tinh hoa',
#   'hình tượng',
#   'mỹ'],
#  ['thực phẩm', 'quần áo'],
#  ['nghệ thuật',
#   'nấu',
#   'đại mỹ',
#   'tương quốc gia',
#   'phương tây',
#   'lúa',
#   'mì ngũ cốc',
#   'yếu',
#   'ẩm thực truyền thống',
#   'mỹ',
#   'nguyên liệu',
#   'nấu',
#   'gà tây',
#   'thịt',
#   'nai',
#   'đuôi',
#   'trắng',
#   'khoai tây',
#   'khoai lang',
#   'bắp',
#   'bí rợ',
#   'trái',
#   'xi',
#   'rô phong',
#   'thực phẩm',
#   'thổ mỹ',
#   'dân',
#   'định cư',
#   'xưa',
#   'châu âu',
#   'chế biến',
#   'thịt',
#   'heo',
#   'nấu',
#   'phương pháp',
#   'nấu',
#   'chậm',
#   'thịt',
#   'bò',
#   'nướng',
#   'bánh',
#   'thịt',
#   'cua',
#   'khoai tây',
#   'thái',
#   'mỏng',
#   'miếng',
#   'chiên',
#   'bánh tròn',
#   'hạt',
#   'sô',
#   'la trộn',
#   'lẫn',
#   'gọi',
#   'chocolate',
#   'chip',
#   'cookie',
#   'thực phẩm',
#   'cống mỹ',
#   'thực phẩm',
#   'chua nô lệ',
#   'phi châu',
#   'phổ biến',
#   'khắp',
#   'miền',
#   'nam',
#   'mỹ',
#   'gốc',
#   'châu phi',
#   'gà',
#   'chiên',
#   'kết hợp',
#   'nghệ thuật',
#   'ẩm thực truyền thống',
#   'mỹ',
#   'gốc',
#   'châu phi',
#   'scotland',
#   'món',
#   'khoái khẩu',
#   'quốc gia',
#   'món',
#   'biểu tượng',
#   'mỹ',
#   'bánh nhân',
#   'táo pizza',
#   'hamburger',
#   'hot',
#   'dog',
#   'món',
#   'đúc kết',
#   'phương thức',
#   'chế biến thức',
#   'đa dạng',
#   'di dân',
#   'châu âu thức',
#   'gọi',
#   'khoai tây',
#   'chiên',
#   'kiểu',
#   'pháp',
#   'món',
#   'mexico',
#   'burritos',
#   'taco',
#   'pasta',
#   'gốc',
#   'khắp',
#   'thưởng thức',
#   'hai',
#   'thập niên',
#   'kỷ xx',
#   'calorie mỹ',
#   'trung bình thể',
#   'hai',
#   'bốn',
#   'trăm',
#   'tỉ lệ',
#   'mỹ thức',
#   'tám',
#   'hai',
#   'trăm',
#   'uống',
#   'xuyên',
#   'hàng',
#   'thức',
#   'mcdonald',
#   'kfc',
#   'burger',
#   'king',
#   'hiện tượng',
#   'nghiên cứu',
#   'phủ',
#   'gọi',
#   'dịch bệnh',
#   'béo',
#   'phì'],
#  ['mỹ',
#   'uống',
#   'cà phê',
#   'trà',
#   'phân nửa',
#   'dân',
#   'uống',
#   'tách',
#   'cà phê',
#   'rượu',
#   'mỹ bourbon',
#   'whiskey',
#   'tennessee',
#   'whiskey',
#   'applejack',
#   'rượu',
#   'rum',
#   'puerto',
#   'rico',
#   'rượu',
#   'martini',
#   'rượu',
#   'trái',
#   'đặc trưng',
#   'mỹ mỹ',
#   'trung bình',
#   'tiêu thụ',
#   'tám',
#   'sáu',
#   'lít',
#   'bia',
#   'bia',
#   'nhẹ',
#   'kiểu',
#   'mỹ điển hình',
#   'thương hiệu',
#   'hàng đầu',
#   'budweiser',
#   'nhẹ',
#   'hương vị',
#   'chủ nhân',
#   'budweiser',
#   'anheuser',
#   'busch',
#   'chiếm lĩnh',
#   'trăm',
#   'thị trường',
#   'bia',
#   'quốc gia',
#   'thập niên',
#   'sản xuất',
#   'tiêu thụ',
#   'rượu',
#   'gia rượu',
#   'ngành',
#   'công nghiệp',
#   'hàng đầu',
#   'california',
#   'ngược',
#   'truyền thống',
#   'châu âu mỹ',
#   'uống',
#   'rượu',
#   'bữa',
#   'thay',
#   'uống',
#   'rượu',
#   'trái',
#   'khai vị',
#   'công nghiệp',
#   'hoa kỳ',
#   'sản xuất',
#   'uống',
#   'sữa',
#   'cam ga',
#   'ưa chuộng',
#   'khắp',
#   'uống',
#   'đường',
#   'chiếm',
#   'chín',
#   'trăm',
#   'calorie',
#   'tiêu thụ',
#   'hàng',
#   'mỹ',
#   'trung bình',
#   'gấp',
#   'đôi',
#   'tỉ lệ',
#   'thập niên',
#   'sản xuất',
#   'hàng đầu',
#   'coca',
#   'cola',
#   'thương hiệu',
#   'công giới',
#   'xếp',
#   'mcdonald'],
#  ['kiểu',
#   'quần áo',
#   'nghiệp vụ',
#   'chỉnh tề',
#   'thời trang',
#   'hoa kỳ',
#   'trung hòa',
#   'nghi thức',
#   'gốc',
#   'văn hóa',
#   'đa dạng mỹ',
#   'phản ánh',
#   'mặc',
#   'di dân',
#   'mũ',
#   'bồi giày',
#   'bồi áo',
#   'khoác',
#   'kiểu',
#   'đi',
#   'xe',
#   'mô tô',
#   'hình tượng',
#   'kiểu',
#   'mỹ',
#   'quần áo',
#   'jeans',
#   'phổ biến',
#   'quần áo',
#   'lao động',
#   'thập niên',
#   'tám',
#   'thương nhân',
#   'levi',
#   'strauss',
#   'di dân',
#   'đức san',
#   'francisco giới',
#   'trẻ',
#   'mỹ',
#   'tiếp kỷ',
#   'quần áo',
#   'jeans',
#   'mặc',
#   'khắp',
#   'lục địa giới',
#   'giai xã hội',
#   'song song',
#   'quần áo',
#   'thông dụng',
#   'bày',
#   'chợ',
#   'quần áo',
#   'jeans thể',
#   'đóng góp',
#   'yếu văn',
#   'hóa mỹ',
#   'thời trang',
#   'giới',
#   'hoa kỳ',
#   'trụ sở',
#   'nhãn hiệu',
#   'thiết kế',
#   'thời trang',
#   'hàng đầu',
#   'ralph',
#   'lauren',
#   'calvin',
#   'klein'],
#  ['thể thao'],
#  ['kỷ xix',
#   'bóng',
#   'chày môn',
#   'thể thao',
#   'quốc gia',
#   'bóng',
#   'bầu dục',
#   'mỹ bóng',
#   'rổ khúc',
#   'côn cầu',
#   'môn',
#   'thể thao',
#   'đồng đội',
#   'chuyên nghiệp',
#   'quốc gia',
#   'bóng',
#   'bầu dục',
#   'đại học',
#   'bóng rổ',
#   'đại học',
#   'hấp',
#   'khán giả',
#   'bóng',
#   'bầu dục',
#   'khía cạnh',
#   'môn',
#   'thể thao',
#   'hoa',
#   'kỳ quyền',
#   'đua',
#   'ngựa',
#   'môn',
#   'thể thao',
#   'nhường',
#   'chỗ',
#   'môn',
#   'golf',
#   'đua',
#   'xe hơi',
#   'hội',
#   'đua',
#   'xe',
#   'nascar',
#   'mặc',
#   'bóng đá',
#   'môn',
#   'thể thao',
#   'chuyên nghiệp',
#   'hàng đầu',
#   'hoa',
#   'kỳ giới',
#   'trẻ giới',
#   'tài tử lứa',
#   'khắp',
#   'đội tuyển',
#   'bóng đá',
#   'nam',
#   'hoa kỳ',
#   'tham dự',
#   'world',
#   'cup',
#   'vô địch',
#   'concacaf',
#   'sáu',
#   'chín',
#   'chín',
#   'hai',
#   'hai',
#   'hai',
#   'hai',
#   'bảy',
#   'hai',
#   'hai',
#   'bảy',
#   'đội tuyển',
#   'bóng đá',
#   'nữ',
#   'quốc gia',
#   'hoa kỳ',
#   'giành',
#   'chức',
#   'vô địch',
#   'giới',
#   'hoa kỳ',
#   'chủ',
#   'world',
#   'cup',
#   'chín',
#   'chín',
#   'bốn',
#   'đăng',
#   'cai giải',
#   'đấu',
#   'hai',
#   'hai',
#   'sáu',
#   'môn',
#   'tennis',
#   'môn',
#   'thể thao',
#   'trời',
#   'ưa chuộng'],
#  ['đa môn',
#   'thể thao',
#   'hoa',
#   'kỳ tiến',
#   'hóa',
#   'môn',
#   'tương châu',
#   'âu nhiên',
#   'bóng rổ',
#   'tiến sĩ',
#   'james',
#   'naismith',
#   'springfield',
#   'massachusetts',
#   'tám',
#   'chín',
#   'môn',
#   'thể thao',
#   'quen',
#   'lacrosse',
#   'môn',
#   'thể thao',
#   'thổ mỹ',
#   'thời',
#   'địa mặt',
#   'thể thao',
#   'môn',
#   'lướt',
#   'ván',
#   'môn',
#   'lướt tuyết',
#   'môn',
#   'mỹ kỷ xx',
#   'liên hệ',
#   'môn',
#   'lướt',
#   'sóng',
#   'môn',
#   'thể thao',
#   'hawaii',
#   'tiếp xúc',
#   'tây phương',
#   'tám',
#   'vận hội',
#   'đăng cai',
#   'hoa kỳ',
#   'bốn',
#   'vận hội',
#   'mùa',
#   'hè',
#   'bốn',
#   'vận hội',
#   'mùa',
#   'đông',
#   'hoa kỳ',
#   'chín',
#   'tổ chức',
#   'kỳ vận hội',
#   'hai',
#   'hai',
#   'tám',
#   'hai',
#   'bảy',
#   'hoa',
#   'kỳ đoạt',
#   'hai',
#   'hai',
#   'hai',
#   'huy chương',
#   'tổng cộng',
#   'kỳ vận hội',
#   'mùa hè',
#   'quốc gia',
#   'kỳ vận hội',
#   'mùa',
#   'đông',
#   'xếp',
#   'hai',
#   'na uy',
#   'vận động viên',
#   'mỹ',
#   'lừng danh giới',
#   'cầu thủ',
#   'bóng',
#   'chày',
#   'babe',
#   'ruth',
#   'võ sĩ',
#   'muhammad',
#   'ali',
#   'cầu thủ',
#   'bóng rổ',
#   'michael',
#   'jordan',
#   'vận động viên',
#   'quần vợt',
#   'pete',
#   'sampras',
#   'vận động viên',
#   'bơi',
#   'lội',
#   'michael',
#   'phelps',
#   'golf',
#   'tiger',
#   'woods'],
#  ['tiểu bang'],
#  ['hoa kỳ',
#   'liên bang',
#   'tiểu bang',
#   'mười',
#   'tiểu bang',
#   'ban đầu',
#   'hậu thân',
#   'mười địa',
#   'nổi loạn',
#   'chống',
#   'cai trị',
#   'vương quốc',
#   'đa',
#   'tiểu bang',
#   'thành lập',
#   'lãnh thổ',
#   'chiếm',
#   'chiến tranh',
#   'phủ',
#   'hoa kỳ',
#   'mua',
#   'quốc gia',
#   'ngoại trừ',
#   'vermont',
#   'texas',
#   'hawaii',
#   'tiểu bang',
#   'xưa',
#   'kia',
#   'cộng hòa',
#   'độc lập',
#   'gia nhập',
#   'liên bang',
#   'trừ',
#   'tạm thời',
#   'tiểu bang',
#   'miền',
#   'nam',
#   'ly',
#   'khai',
#   'nội chiến',
#   'hoa kỳ',
#   'tiểu bang',
#   'hoa',
#   'kỳ thu',
#   'lịch sử',
#   'hoa',
#   'kỳ thời',
#   'lập quốc',
#   'tiểu bang',
#   'thành lập',
#   'lãnh thổ',
#   'tiểu bang',
#   'tồn kentucky',
#   'tách',
#   'virginia',
#   'tennessee',
#   'bắc',
#   'carolina',
#   'maine',
#   'massachusetts tây',
#   'virginia',
#   'tách',
#   'virginia',
#   'nội chiến',
#   'hoa kỳ',
#   'sáp nhập',
#   'trở',
#   'ranh giới',
#   'tiểu bang',
#   'trừ',
#   'maryland',
#   'virginia',
#   'nhường',
#   'đất',
#   'thành lập',
#   'đặc',
#   'khu',
#   'columbia',
#   'nhường',
#   'đất',
#   'georgia',
#   'rộng',
#   'tiểu bang',
#   'missouri',
#   'nevada',
#   'hawaii',
#   'tiểu bang',
#   'gia nhạp',
#   'liên bang',
#   'hai',
#   'tám',
#   'chín',
#   'chín'],
#  ['tiểu bang',
#   'bao phủ',
#   'lãnh thổ',
#   'rộng',
#   'hoa kỳ',
#   'lãnh thổ thể',
#   'chia cắt',
#   'quốc gia',
#   'đặc',
#   'khu',
#   'columbia',
#   'thủ đô',
#   'hoa',
#   'kỳ đảo',
#   'palmyra',
#   'lãnh thổ hợp',
#   'hoa kỳ thái bình dương',
#   'bốn',
#   'lãnh thổ',
#   'hoa kỳ',
#   'hợp thức',
#   'liên bang',
#   'trị thể',
#   'tương lai',
#   'thí dụ',
#   'puerto',
#   'rico phép',
#   'tiến hành',
#   'trưng cầu dân trị',
#   'lãnh thổ',
#   'nguyên'],
#  ['lễ', 'liên bang'],
#  ['lễ',
#   'liên bang',
#   'hoa kỳ',
#   'đa',
#   'lễ',
#   'hoa kỳ',
#   'ấn định',
#   'kiểu',
#   'tuần',
#   'kiểu',
#   'việt',
#   'quen',
#   'lễ',
#   'tạ',
#   'ơn',
#   'thí dụ',
#   'lễ',
#   'rơi',
#   'tư nghĩa',
#   'đầu ta',
#   'đếm',
#   'hai',
#   'tư lễ',
#   'tạ',
#   'ơn'],
#  [],
#  ['lý', 'quang diệu', 'sách', 'bàn', 'trung quốc', 'hoa', 'kỳ giới', 'hoa kỳ'],
#  ['triết', 'học trị', 'alexis de', 'tocqueville', 'mỹ'],
#  ['tổng thống', 'mỹ abraham', 'lincoln'],
#  ['doanh nhân', 'elon', 'musk'],
#  ['tổng thống', 'mỹ george', 'w', 'bush'],
#  ['tổng thống', 'mỹ barack', 'obama'],
#  ['liên kết'],
#  ['hoa', 'kỳ nét', 'đặc trưng', 'toàn cảnh', 'mỹ'],
#  ['đại sứ quán', 'hoa kỳ', 'việt nam'],
#  ['firstgov', 'website thức', 'phủ', 'hoa kỳ']]

# %% [markdown]
# # 3. Word2Vec

# %%
# init the Word2Vec model with sample data
model = Word2Vec(sample_tokens, vector_size = 300, window = 5, min_count = 1, workers = 4)

# %%
# vectorlize words in a doc
word_vectors = model.wv[sample_tokens[3]]

# using average word2vec
avg_word2vec = word_vectors.mean(axis=0)

len(word_vectors), word_vectors, avg_word2vec
# Out:
# (25,
#  array([[ 0.00707596,  0.01674215, -0.00166502, ..., -0.01390744,
#           0.00977892, -0.00228943],
#         [-0.00214355,  0.00294003,  0.00099316, ..., -0.00412652,
#           0.00320609, -0.00089672],
#         [ 0.0291292 ,  0.05989324, -0.00465175, ..., -0.04576759,
#           0.03807134, -0.02072483],
#         ...,
#         [ 0.00172768,  0.00057977, -0.00138901, ..., -0.00563658,
#          -0.00063227, -0.00150506],
#         [ 0.01294287,  0.03052992, -0.00213772, ..., -0.02475156,
#           0.01994115, -0.01044608],
#         [ 0.0267437 ,  0.06290844, -0.00099102, ..., -0.05427884,
#           0.04390847, -0.0238958 ]], dtype=float32),
#  array([ 0.01710799,  0.03775597, -0.00203975,  0.01951701, -0.00117384,
#         -0.03525405,  0.02620503,  0.0696658 ,  0.01434422, -0.01277342,
#          0.00139536, -0.02434053, -0.00651818,  0.01014628, -0.02311089,
#         -0.02029221,  0.01262633, -0.00881075,  0.01312512, -0.00689695,
#         -0.02493167, -0.00075642,  0.02551161,  0.00065795,  0.03279236,
#          0.00158435, -0.03283806, -0.00864774, -0.02437378, -0.02504059,
#          0.01040123, -0.01907626, -0.00880376, -0.01581644, -0.00062053,
#          0.00662676,  0.00979063, -0.0180748 ,  0.00100437, -0.02023731,
#         -0.0206732 , -0.00702386,  0.00525952, -0.00771179,  0.0222058 ,
#          0.03802664, -0.00022296,  0.01845262, -0.00029975,  0.01773287,
#          0.00551796,  0.00082146, -0.01456449,  0.00994975, -0.00274257,
#          0.03851842,  0.00900388, -0.00668201,  0.01197886, -0.00687205,
#         -0.01885565, -0.01323845, -0.0021868 ,  0.00551032,  0.01139254,
#          0.01528017, -0.00432245,  0.01359605, -0.01540357, -0.00313244,
#         -0.00478901,  0.01110123,  0.01676755, -0.02833735,  0.00370381,
#          0.02816258, -0.02941518,  0.00227718, -0.01226373,  0.02054352,
#         -0.01385102, -0.02531257,  0.00245513,  0.04912563,  0.02910561,
#          0.00768242, -0.01056773,  0.00093082,  0.03599056,  0.01066619,
#          0.02830308, -0.02789757,  0.02335135, -0.00632471,  0.02314281,
#          0.02109045,  0.02766106, -0.01166912, -0.01265052,  0.02821897,
#          0.00397324,  0.0135573 ,  0.02278122,  0.02040706, -0.00078822,
#         -0.01926666, -0.00261488,  0.00099159, -0.02003378,  0.0175576 ,
#         -0.03496339, -0.01058709,  0.00700792,  0.01859192,  0.01117061,
#          0.01681018, -0.0018931 , -0.005962  ,  0.03514634, -0.03758495,
#          0.01518214,  0.02175466,  0.01373427,  0.00512676, -0.02009961,
#          0.02180273,  0.02042022, -0.03131262, -0.00189994,  0.01527379,
#         -0.00360797,  0.03423913,  0.00820903, -0.02446577,  0.00544722,
#          0.01321445, -0.01006372, -0.02007398, -0.03123639, -0.03593906,
#          0.01135031, -0.03569193, -0.00513595,  0.02127363,  0.0120061 ,
#         -0.00818792, -0.04312755, -0.01335527,  0.02636483, -0.01280188,
#          0.00633353, -0.05444334, -0.02553311, -0.01400693,  0.02010569,
#          0.01263675, -0.03089252, -0.00361058, -0.00719253,  0.02627137,
#          0.0055891 ,  0.02067228, -0.02441072,  0.02255696, -0.02541919,
#          0.00646238, -0.00229342,  0.00266759,  0.00234097,  0.05157747,
#         -0.00859181, -0.00949067,  0.02241034,  0.00111315, -0.00878754,
#         -0.00769371, -0.0108469 , -0.01992645, -0.01203741, -0.01104924,
#         -0.0118899 ,  0.01647628, -0.03205021, -0.00570914, -0.00130657,
#          0.00851437,  0.05119453,  0.03501616,  0.01102566, -0.02726611,
#         -0.0049769 , -0.00397001, -0.04184496, -0.00619161, -0.0106888 ,
#         -0.03360803, -0.0018502 , -0.02579966,  0.02470835, -0.00864237,
#         -0.01890553, -0.00047128, -0.0027386 , -0.01468001, -0.00881715,
#         -0.0008953 , -0.01185187,  0.00356962,  0.00395262,  0.00173842,
#          0.00533238, -0.02665051, -0.00610384, -0.00086293,  0.02282038,
#         -0.03295229, -0.02551159, -0.04377428, -0.04546463, -0.02300534,
#          0.01859278, -0.00468321, -0.01953362, -0.0241547 , -0.01423438,
#         -0.01415686,  0.0116867 ,  0.00973608, -0.0323558 ,  0.02213691,
#          0.02630121,  0.00616891, -0.00637319,  0.03212076, -0.02209308,
#          0.01178423,  0.00059237, -0.00155867,  0.00575796, -0.04609634,
#          0.00380714, -0.0205901 , -0.0188495 ,  0.00521477,  0.00667611,
#         -0.0210015 ,  0.00384863, -0.00152074, -0.00434246,  0.01833228,
#          0.01689373,  0.01971093, -0.00020264,  0.00389372, -0.04143333,
#         -0.01739525,  0.03897532,  0.01206869, -0.04052502, -0.02391457,
#          0.02151786,  0.02499838,  0.00932169, -0.05193502, -0.03888566,
#         -0.00277167, -0.00016609,  0.01096244, -0.02477648,  0.00113233,
#         -0.02144041,  0.00608263, -0.00018511, -0.0030679 ,  0.03018486,
#          0.0055469 ,  0.02851686,  0.00144312, -0.03976289, -0.00530899,
#          0.01449383,  0.01138718, -0.01223397,  0.02665421, -0.0025356 ,
#          0.00364329, -0.04824083,  0.01385995,  0.01422764,  0.02933728,
#          0.00655053,  0.04981589,  0.04456234,  0.01060288,  0.02995961,
#          0.03686511,  0.00236928, -0.03127355,  0.02391551, -0.01473001],
#        dtype=float32))

# %%
# find similar word in model
similar_words = model.wv.most_similar("thành phố")
print(similar_words)
# Out:
# [('hai', 0.9991716146469116), ('sài gòn', 0.9991375803947449), ('hoa kỳ', 0.9991369247436523), ('việt nam', 0.9991288185119629), ('đất', 0.9991065263748169), ('thành', 0.9990755319595337), ('thụy điển', 0.9990288019180298), ('tám', 0.9990015029907227), ('khu vực', 0.9989915490150452), ('bảy', 0.9989913702011108)]

# %%
# save model 
model.save('/kaggle/working/word2vec_viwik18.model')
# load pre-trained model
model = Word2Vec.load('/kaggle/working/word2vec_viwik18.model')
